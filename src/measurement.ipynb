# %%
import requests
import pandas as pd

# %%
valid_probes = []
current_page = "https://atlas.ripe.net:443/api/v2/probes/?status=1"

while True:
    page = requests.get(current_page)
    if page.json()['next'] != None:
        current_page = page.json()['next']
    else:
        break
    valid_probes += page.json()['results']

valid_probe_pd = pd.DataFrame(valid_probes)

# %%
valid_probe_pd

# %%
valid_probe_pd['id'].value_counts().index.to_list()

# %%
def findStableTag(x):
    for tag in x:
        for index, item in tag.items():
            if item == "system-ipv4-stable-1d":
                return True
    return False

# %%
valid_probe_pd["stable"] = valid_probe_pd['tags'].apply(lambda x: findStableTag(x))

# %%
valid_probe_pd["stable"].value_counts()

# %%
valid_probe_pd["tags"].loc[1]

# %%
import datetime

# %%
sprobe_lst = valid_probe_pd[valid_probe_pd['stable']==True]['id'].to_list()

# %%
filename = datetime.date.today().strftime("%Y-%m-%d")
with open(f"../dataset/srprobe_lst/{filename}", "w+") as f:
    f.write(" ".join(map(str,sprobe_lst)))

# %% [markdown]
# # measurement

# %%
import measurement
import analysis

# %%
test_analysis = analysis.analysis(dc_name="imperva",target=["45.60.155.44", "45.60.151.44", "45.60.159.44", "45.60.167.44", "45.60.171.44", "45.60.163.44"], mtr_lst=[44104396, 44104397, 44104399, 44104400, 44104401, 44104402, 44104404, 44104405, 44104406, 44104407])

# %%
test_analysis.measure.measure_pd
# Out:
#       index    fw   mver   lts     endtime        dst_name         ttr  \
# 0         0  5040  2.4.1    -1  1661405722  www.stamps.com  205.282194
# 1         1  4790    NaN    59  1661405999  www.stamps.com         NaN
# 2         2  4790    NaN   495  1661406003  www.stamps.com         NaN
# 3         3  5020  2.2.1  4285  1661406002  www.stamps.com   10.942798
# 4         4  5020  2.2.1    18  1661405996  www.stamps.com  150.272506
# ...     ...   ...    ...   ...         ...             ...         ...
# 9333    926  5070  2.6.1    43  1661406123  www.stamps.com  122.148655
# 9334    927  5070  2.6.1    18  1661406139  www.stamps.com  372.621231
# 9335    928  5070  2.6.1    23  1661406126  www.stamps.com  208.964814
# 9336    929  5070  2.6.1    35  1661406124  www.stamps.com  157.069524
# 9337    930  5070  2.6.1     2  1661406137  www.stamps.com   44.019354
#
#           dst_addr         src_addr proto  ...           timestamp  \
# 0     45.60.155.44       172.17.0.2  ICMP  ... 2022-08-25 05:34:46
# 1     45.60.155.44   192.168.178.26  ICMP  ... 2022-08-25 05:39:58
# 2     45.60.159.44    192.168.1.137  ICMP  ... 2022-08-25 05:39:54
# 3     45.60.155.44    109.49.34.111  ICMP  ... 2022-08-25 05:39:45
# 4     45.60.155.44     81.84.88.107  ICMP  ... 2022-08-25 05:39:51
# ...            ...              ...   ...  ...                 ...
# 9333  45.60.155.44     86.109.17.27  ICMP  ... 2022-08-25 05:42:03
# 9334  45.60.155.44   192.168.211.12  ICMP  ... 2022-08-25 05:42:06
# 9335  45.60.155.44      172.20.0.38  ICMP  ... 2022-08-25 05:42:05
# 9336  45.60.155.44  185.188.244.180  ICMP  ... 2022-08-25 05:42:04
# 9337  45.60.155.44    192.168.2.250  ICMP  ... 2022-08-25 05:42:04
#
#         msm_name             from        type  group_id  stored_timestamp  \
# 0     Traceroute    82.56.185.254  traceroute  44104396        1661406037
# 1     Traceroute    45.138.229.91  traceroute  44104396        1661406000
# 2     Traceroute    144.134.58.81  traceroute  44104396        1661406004
# 3     Traceroute    109.49.34.111  traceroute  44104396        1661406009
# 4     Traceroute     81.84.88.107  traceroute  44104396        1661406001
# ...          ...              ...         ...       ...               ...
# 9333  Traceroute     86.109.17.27  traceroute  44104407        1661406125
# 9334  Traceroute   185.64.223.156  traceroute  44104407        1661406139
# 9335  Traceroute    185.76.192.34  traceroute  44104407        1661406126
# 9336  Traceroute  185.188.244.180  traceroute  44104407        1661406125
# 9337  Traceroute    84.101.103.92  traceroute  44104407        1661406138
#
#                                              reduce_hop            p_hop  \
# 0     [{'hop': 1, 'ip': '172.17.0.1', 'rtt': 0.133},...    212.133.7.122
# 1     [{'hop': 1, 'ip': '192.168.178.1', 'rtt': 1.89...    213.19.203.66
# 2     [{'hop': 1, 'ip': '192.168.1.1', 'rtt': 3.021}...    58.163.92.174
# 3     [{'hop': 1, 'ip': '*', 'rtt': -1}, {'hop': 2, ...   87.186.181.234
# 4     [{'hop': 1, 'ip': '10.20.127.254', 'rtt': 9.08...   87.186.181.234
# ...                                                 ...              ...
# 9333  [{'hop': 1, 'ip': '86.109.19.254', 'rtt': 0.43...   80.249.208.124
# 9334  [{'hop': 1, 'ip': '192.168.211.1', 'rtt': 0.4}...   62.115.187.154
# 9335  [{'hop': 1, 'ip': '172.20.0.254', 'rtt': 0.353...   62.115.187.155
# 9336  [{'hop': 1, 'ip': '185.188.244.130', 'rtt': 0....     80.81.193.87
# 9337  [{'hop': 1, 'ip': '192.168.2.254', 'rtt': 0.64...  213.242.111.235
#
#          rtt   p_rtt
# 0      8.860   9.281
# 1      6.434   7.629
# 2     22.258  22.726
# 3     52.684  55.493
# 4     66.634  68.227
# ...      ...     ...
# 9333   3.048   3.016
# 9334  23.966  23.945
# 9335  29.789  30.131
# 9336   7.442   7.464
# 9337  29.317  29.491
#
# [9201 rows x 26 columns]

# %%
test_analysis.mapsite()
# Out:
# geolocating the phop...
# 'NoneType' object has no attribute 'split'
# something error when generating phop_pd

# %%
test_analysis.phop_pd
# Out:
#                  p_hop rdns-geo                           ipinfo-geo  \
# 80.81.193.87      1045     None  DE|Frankfurt am Main|50.1153,8.6823
# 87.186.181.234     448     None  DE|Frankfurt am Main|50.1112,8.6831
# 80.249.208.124     437     None          NL|Amsterdam|52.3740,4.8897
# 195.122.180.66     388     None  DE|Frankfurt am Main|50.1155,8.6842
# 62.115.187.154     371     None        DK|Copenhagen|55.6759,12.5655
# ...                ...      ...                                  ...
# 217.5.88.250         1     None  DE|Frankfurt am Main|50.1155,8.6842
# 193.114.170.227      1     None            GB|London|51.5085,-0.1257
# 196.25.245.150       1     None     ZA|Johannesburg|-26.2023,28.0436
# 46.59.112.142        1     None         SE|Stockholm|59.3294,18.0687
# 172.16.189.54        1     None                                 None
#
#                                               maxmind-geo nearest_prb_loc
# 80.81.193.87                                         None            None
# 87.186.181.234                                       None            None
# 80.249.208.124        Netherlands|Schiphol|52.2973,4.7946            None
# 195.122.180.66   Germany|Frankfurt am Main|50.1188,8.6843            None
# 62.115.187.154                                       None            None
# ...                                                   ...             ...
# 217.5.88.250                                         None            None
# 193.114.170.227                                      None            None
# 196.25.245.150       South Africa|George|-33.9638,22.4487            None
# 46.59.112.142            Sweden|Stockholm|59.3287,18.0717            None
# 172.16.189.54                                        None            None
#
# [249 rows x 5 columns]

# %%
measure_pd = test_analysis.measure.measure_pd

# %%
measure_pd
# Out:
#       index    fw   mver   lts     endtime        dst_name         ttr  \
# 0         0  5040  2.4.1    -1  1661405722  www.stamps.com  205.282194
# 1         1  4790    NaN    59  1661405999  www.stamps.com         NaN
# 2         2  4790    NaN   495  1661406003  www.stamps.com         NaN
# 3         3  5020  2.2.1  4285  1661406002  www.stamps.com   10.942798
# 4         4  5020  2.2.1    18  1661405996  www.stamps.com  150.272506
# ...     ...   ...    ...   ...         ...             ...         ...
# 9333    926  5070  2.6.1    43  1661406123  www.stamps.com  122.148655
# 9334    927  5070  2.6.1    18  1661406139  www.stamps.com  372.621231
# 9335    928  5070  2.6.1    23  1661406126  www.stamps.com  208.964814
# 9336    929  5070  2.6.1    35  1661406124  www.stamps.com  157.069524
# 9337    930  5070  2.6.1     2  1661406137  www.stamps.com   44.019354
#
#           dst_addr         src_addr proto  ...           timestamp  \
# 0     45.60.155.44       172.17.0.2  ICMP  ... 2022-08-25 05:34:46
# 1     45.60.155.44   192.168.178.26  ICMP  ... 2022-08-25 05:39:58
# 2     45.60.159.44    192.168.1.137  ICMP  ... 2022-08-25 05:39:54
# 3     45.60.155.44    109.49.34.111  ICMP  ... 2022-08-25 05:39:45
# 4     45.60.155.44     81.84.88.107  ICMP  ... 2022-08-25 05:39:51
# ...            ...              ...   ...  ...                 ...
# 9333  45.60.155.44     86.109.17.27  ICMP  ... 2022-08-25 05:42:03
# 9334  45.60.155.44   192.168.211.12  ICMP  ... 2022-08-25 05:42:06
# 9335  45.60.155.44      172.20.0.38  ICMP  ... 2022-08-25 05:42:05
# 9336  45.60.155.44  185.188.244.180  ICMP  ... 2022-08-25 05:42:04
# 9337  45.60.155.44    192.168.2.250  ICMP  ... 2022-08-25 05:42:04
#
#         msm_name             from        type  group_id  stored_timestamp  \
# 0     Traceroute    82.56.185.254  traceroute  44104396        1661406037
# 1     Traceroute    45.138.229.91  traceroute  44104396        1661406000
# 2     Traceroute    144.134.58.81  traceroute  44104396        1661406004
# 3     Traceroute    109.49.34.111  traceroute  44104396        1661406009
# 4     Traceroute     81.84.88.107  traceroute  44104396        1661406001
# ...          ...              ...         ...       ...               ...
# 9333  Traceroute     86.109.17.27  traceroute  44104407        1661406125
# 9334  Traceroute   185.64.223.156  traceroute  44104407        1661406139
# 9335  Traceroute    185.76.192.34  traceroute  44104407        1661406126
# 9336  Traceroute  185.188.244.180  traceroute  44104407        1661406125
# 9337  Traceroute    84.101.103.92  traceroute  44104407        1661406138
#
#                                              reduce_hop            p_hop  \
# 0     [{'hop': 1, 'ip': '172.17.0.1', 'rtt': 0.133},...    212.133.7.122
# 1     [{'hop': 1, 'ip': '192.168.178.1', 'rtt': 1.89...    213.19.203.66
# 2     [{'hop': 1, 'ip': '192.168.1.1', 'rtt': 3.021}...    58.163.92.174
# 3     [{'hop': 1, 'ip': '*', 'rtt': -1}, {'hop': 2, ...   87.186.181.234
# 4     [{'hop': 1, 'ip': '10.20.127.254', 'rtt': 9.08...   87.186.181.234
# ...                                                 ...              ...
# 9333  [{'hop': 1, 'ip': '86.109.19.254', 'rtt': 0.43...   80.249.208.124
# 9334  [{'hop': 1, 'ip': '192.168.211.1', 'rtt': 0.4}...   62.115.187.154
# 9335  [{'hop': 1, 'ip': '172.20.0.254', 'rtt': 0.353...   62.115.187.155
# 9336  [{'hop': 1, 'ip': '185.188.244.130', 'rtt': 0....     80.81.193.87
# 9337  [{'hop': 1, 'ip': '192.168.2.254', 'rtt': 0.64...  213.242.111.235
#
#          rtt   p_rtt
# 0      8.860   9.281
# 1      6.434   7.629
# 2     22.258  22.726
# 3     52.684  55.493
# 4     66.634  68.227
# ...      ...     ...
# 9333   3.048   3.016
# 9334  23.966  23.945
# 9335  29.789  30.131
# 9336   7.442   7.464
# 9337  29.317  29.491
#
# [9201 rows x 26 columns]

# %%
test_analysis.measure.get_probe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-aa1c2d6f7b49> in <module>
# ----> 1 test_analysis.measure.get_probe()
#
# ~/jupyter_projects/anytool/src/measurement.py in get_probe(self)
#      43         self.valid_probe_pd = pd.DataFrame(valid_probes)
#      44         self.valid_probe_pd["stable"] = self.valid_probe_pd['tags'].apply(lambda x: findStableTag(x))  #find all stable probe
# ---> 45         self.valid_probe_pd["location"] = self.valid_probe_pd.apply(lambda x:[x['latitude'], x['longitude']], axis=1)
#      46         sprobe_lst = self.valid_probe_pd[self.valid_probe_pd['stable']==True]['id'].to_list()
#      47
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# ~/jupyter_projects/anytool/src/measurement.py in <lambda>(x)
#      43         self.valid_probe_pd = pd.DataFrame(valid_probes)
#      44         self.valid_probe_pd["stable"] = self.valid_probe_pd['tags'].apply(lambda x: findStableTag(x))  #find all stable probe
# ---> 45         self.valid_probe_pd["location"] = self.valid_probe_pd.apply(lambda x:[x['latitude'], x['longitude']], axis=1)
#      46         sprobe_lst = self.valid_probe_pd[self.valid_probe_pd['stable']==True]['id'].to_list()
#      47
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# /home/test/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'latitude'

# %%
test_analysis.measure.valid_probe_pd["geometry"].loc[0]
# Out:
# {'type': 'Point', 'coordinates': [4.9275, 52.3475]}

# %%
test_analysis.measure.valid_probe_pd["location"] = test_analysis.measure.valid_probe_pd["geometry"].str['coordinates']

# %%
test_analysis.measure.valid_probe_pd
# Out:
#             address_v4                           address_v6   asn_v4  \
# 0                 None   2a10:3781:e22:1:220:4aff:fec8:23d7      NaN
# 1         77.174.76.85  2a02:a467:f500:1:220:4aff:fec8:2532   1136.0
# 2                 None                                 None  50266.0
# 3       82.217.219.124                                 None  33915.0
# 4          83.81.82.33                                 None  33915.0
# ...                ...                                  ...      ...
# 12895   188.224.28.148                                 None  47206.0
# 12896     192.33.93.10          2001:67c:10ec:3548:8000::79    559.0
# 12897   62.113.228.110                                 None  47447.0
# 12898   192.69.103.154                                 None  54617.0
# 12899  216.238.107.208                                 None  20473.0
#
#          asn_v6 country_code                      description  \
# 0      206238.0           NL          Robert #1 100/10 XS4All
# 1        1136.0           NL               Ανδρέας@Άμστερνταμ
# 2           NaN           NL                              UPC
# 3           NaN           NL       @milan ZIGGO 200/20 Mbit/s
# 4           NaN           NL  @dfk ZIGGO 1000/75 Mbit/s Cable
# ...         ...          ...                              ...
# 12895       NaN           FR                             None
# 12896     559.0           CH                           NetSec
# 12897       NaN           DE                             None
# 12898       NaN           US
# 12899       NaN           BR                     Vultr BR GRU
#
#        first_connected                                           geometry  \
# 0           1288367583  {'type': 'Point', 'coordinates': [4.9275, 52.3...
# 1           1288372715  {'type': 'Point', 'coordinates': [4.9375, 52.3...
# 2           1288619463  {'type': 'Point', 'coordinates': [4.9175, 52.3...
# 3           1288686777  {'type': 'Point', 'coordinates': [6.0075, 51.2...
# 4           1288619044  {'type': 'Point', 'coordinates': [6.0375, 51.2...
# ...                ...                                                ...
# 12895       1686237736  {'type': 'Point', 'coordinates': [-1.4605, 48....
# 12896       1686240624  {'type': 'Point', 'coordinates': [8.5495, 47.3...
# 12897       1686242429  {'type': 'Point', 'coordinates': [10.3095, 53....
# 12898       1686250316  {'type': 'Point', 'coordinates': [-97.8205, 37...
# 12899       1686269488  {'type': 'Point', 'coordinates': [-46.7805, -2...
#
#             id  is_anchor  ...  last_connected        prefix_v4  \
# 0            1      False  ...      1687166889             None
# 1            3      False  ...      1687166889    77.174.0.0/16
# 2            6      False  ...      1687166889    82.174.0.0/16
# 3            7      False  ...      1687166889  82.217.128.0/17
# 4            8      False  ...      1687166889     83.80.0.0/14
# ...        ...        ...  ...             ...              ...
# 12895  1005953      False  ...      1687167101   188.224.0.0/17
# 12896  1005954      False  ...      1687167101   192.33.92.0/22
# 12897  1005955      False  ...      1687167101  62.113.228.0/22
# 12898  1005956      False  ...      1687167101  192.69.103.0/24
# 12899  1005957      False  ...      1687167101  216.238.96.0/19
#
#                 prefix_v6                                             status  \
# 0          2a10:3780::/29  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 1          2a02:a400::/25  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 2                    None  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 3                    None  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 4                    None  {'id': 1, 'name': 'Connected', 'since': '2023-...
# ...                   ...                                                ...
# 12895                None  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 12896  2001:67c:10ec::/48  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 12897                None  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 12898                None  {'id': 1, 'name': 'Connected', 'since': '2023-...
# 12899                None  {'id': 1, 'name': 'Connected', 'since': '2023-...
#
#       status_since                                               tags  \
# 0       1685124966  [{'name': 'DSL', 'slug': 'dsl'}, {'name': 'Hom...
# 1       1685440128  [{'name': 'Home', 'slug': 'home'}, {'name': 'N...
# 2       1687166683  [{'name': 'Home', 'slug': 'home'}, {'name': 'N...
# 3       1680813859  [{'name': 'Cable', 'slug': 'cable'}, {'name': ...
# 4       1687048112  [{'name': 'Cable', 'slug': 'cable'}, {'name': ...
# ...            ...                                                ...
# 12895   1686237736  [{'name': 'system: Resolves A Correctly', 'slu...
# 12896   1686240624  [{'name': 'Cable', 'slug': 'cable'}, {'name': ...
# 12897   1686388486  [{'name': 'system: Auto GEOIP city', 'slug': '...
# 12898   1686250316  [{'name': 'Datacentre', 'slug': 'datacentre'},...
# 12899   1686923707  [{'name': 'Datacentre', 'slug': 'datacentre'},...
#
#       total_uptime   type stable              location
# 0        386952869  Probe  False     [4.9275, 52.3475]
# 1        387264712  Probe   True     [4.9375, 52.3685]
# 2        345664429  Probe  False     [4.9175, 52.3505]
# 3        388672989  Probe  False     [6.0075, 51.2005]
# 4        385165946  Probe   True     [6.0375, 51.2315]
# ...            ...    ...    ...                   ...
# 12895       929365  Probe   True    [-1.4605, 48.1185]
# 12896       926477  Probe   True     [8.5495, 47.3795]
# 12897       924436  Probe  False    [10.3095, 53.9395]
# 12898       916785  Probe   True   [-97.8205, 37.7505]
# 12899       894318  Probe  False  [-46.7805, -23.4895]
#
# [12900 rows x 21 columns]

# %%
valid_probe_pd = test_analysis.measure.valid_probe_pd

# %%
def hoiho(rdns):
    result = requests.get(f"https://api.hoiho.caida.org/lookups/{rdns}")    #extract geolocation from hostname
    try:
        result = eval(result.text)
        if "matches" in result.keys():
            loc = f"{result['matches']['place']}|{result['matches']['lat']},{result['matches']['lon']}"
            return loc
        return None
    except:
        #print(f"something wrong when using hoiho:{result}")
        return None

# %%
import socket
def extracerDNS(ip):
    try:
        rdns = socket.gethostbyaddr(ip)[0]
        return hoiho(rdns)
    except:
        return None

# %%
def ipinfo(ip):
    loc = requests.get("https://ipinfo.io/%s/json?token=2c732d429c11a8"%ip).json()
    if "country" in loc:
        return f"{loc['country']}|{loc['city']}|{loc['loc']}"
    else:
        return None

# %%
import geoip2.database
geo_reader = geoip2.database.Reader("../dataset/geoip2/GeoLite2-City.mmdb")
def maxmind(ip):
    try:
        response = geo_reader.city(ip)
        return response.country.name + "|" + response.city.name + "|" + response.location.latitude.__str__() +',' + response.location.longitude.__str__()
    except:
        return None

# %%
def nearestPrb(phop):
    try:
        prb_pd = measure_pd[measure_pd['p_hop'] == phop].sort_values('p_rtt')
        i = 0
        loc = []
        while(i < len(prb_pd) and len(loc) == 0):
            cur_prb = measure_pd[measure_pd['p_hop'] == phop].sort_values('p_rtt').iloc[i]
            loc = valid_probe_pd[valid_probe_pd['id'] == cur_prb["prb_id"]]['location'].to_list()
            i += 1
#         cur_prb = measure_pd[measure_pd['p_hop'] == phop].sort_values('p_rtt').iloc[0]        #the closest probe to the phop
        if len(loc) > 0:
            return (loc[0][::-1], cur_prb['p_rtt'])
        else:
            return None
    except:
        return None

# %%
measure_pd[measure_pd['p_hop'] == "80.81.193.87"].sort_values('p_rtt').iloc[0]
# Out:
# index                                                              30
# fw                                                               5040
# mver                                                            2.4.1
# lts                                                                35
# endtime                                                    1661405988
# dst_name                                               www.stamps.com
# ttr                                                         21.512318
# dst_addr                                                 45.60.155.44
# src_addr                                                   172.16.8.2
# proto                                                            ICMP
# af                                                                  4
# size                                                               48
# paris_id                                                            1
# result              [{'hop': 1, 'result': [{'from': '172.16.8.1', ...
# msm_id                                                       44104396
# prb_id                                                        1003332
# timestamp                                         2022-08-25 05:39:48
# msm_name                                                   Traceroute
# from                                                   130.162.54.130
# type                                                       traceroute
# group_id                                                     44104396
# stored_timestamp                                           1661405989
# reduce_hop          [{'hop': 1, 'ip': '172.16.8.1', 'rtt': 0.042},...
# p_hop                                                    80.81.193.87
# rtt                                                             0.386
# p_rtt                                                           0.429
# Name: 30, dtype: object

# %%
valid_probe_pd[valid_probe_pd['id']==1]['location'].to_list()[0][::-1]
# Out:
# [52.3475, 4.9275]

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="xxx")
geolocator.reverse("32.8885 -117.1815").address
# Out:
# '6320, Nancy Ridge Drive, Sorrento Valley, San Diego, San Diego County, California, 92121, United States'

# %%
from geopy.distance import great_circle
def extractDist(data):
    try:
        geos = [data["rdns-geo"], data["ipinfo-geo"], data["maxmind-geo"]]
        if data['nearest_prb_loc'] != None:
            lat,lon = data['nearest_prb_loc'][0][0], data['nearest_prb_loc'][0][1]
            dist = []
            for each in geos:
                if each != None:
                    cur_lat, cur_lon = each.split("|")[-1].split(",")
                    dist.append((great_circle((cur_lat,cur_lon),(lat,lon)).km, each))
            if len(dist) == 0:
                if data['nearest_prb_loc'][1] < 1:
                    return geolocator.reverse(f"{lat} {lon}").address + '|' + str(lat)+ ',' + str(lon) #return closest probe's location
                else:
                    return None
            opt_choice = sorted(dist)[0]
            if opt_choice[0] < 600 and data['nearest_prb_loc'][1] < 6:       #if the distance to the nearest probe is less than 600 km and the rtt to the phop is less than 6 ms
                return opt_choice[1]
            else:
                return None
        else:
            return data["ipinfo-geo"]
    except Exception as e:
        return None

# %%
phop_pd = pd.DataFrame(measure_pd['p_hop'].value_counts())

# %%
phop_pd = phop_pd[phop_pd.index!='*']

# %%
phop_pd['rdns-geo'] = phop_pd.apply(lambda x: extracerDNS(x.name), axis=1)

# %%
phop_pd['ipinfo-geo'] = phop_pd.apply(lambda x: ipinfo(x.name), axis=1)

# %%
phop_pd['maxmind-geo'] = phop_pd.apply(lambda x: maxmind(x.name), axis=1)

# %%
phop_pd['nearest_prb_loc'] = phop_pd.apply(lambda x: nearestPrb(x.name), axis=1)

# %%
phop_pd
# Out:
#                  p_hop rdns-geo                           ipinfo-geo  \
# 80.81.193.87      1045     None  DE|Frankfurt am Main|50.1153,8.6823
# 87.186.181.234     448     None  DE|Frankfurt am Main|50.1112,8.6831
# 80.249.208.124     437     None          NL|Amsterdam|52.3740,4.8897
# 195.122.180.66     388     None  DE|Frankfurt am Main|50.1155,8.6842
# 62.115.187.154     371     None        DK|Copenhagen|55.6759,12.5655
# ...                ...      ...                                  ...
# 217.5.88.250         1     None  DE|Frankfurt am Main|50.1155,8.6842
# 193.114.170.227      1     None            GB|London|51.5085,-0.1257
# 196.25.245.150       1     None     ZA|Johannesburg|-26.2023,28.0436
# 46.59.112.142        1     None         SE|Stockholm|59.3294,18.0687
# 172.16.189.54        1     None                                 None
#
#                                               maxmind-geo  \
# 80.81.193.87                                         None
# 87.186.181.234                                       None
# 80.249.208.124        Netherlands|Schiphol|52.2973,4.7946
# 195.122.180.66   Germany|Frankfurt am Main|50.1188,8.6843
# 62.115.187.154                                       None
# ...                                                   ...
# 217.5.88.250                                         None
# 193.114.170.227                                      None
# 196.25.245.150       South Africa|George|-33.9638,22.4487
# 46.59.112.142            Sweden|Stockholm|59.3287,18.0717
# 172.16.189.54                                        None
#
#                                           nearest_prb_loc  \
# 80.81.193.87                    ([50.1205, 8.7405], 0.43)
# 87.186.181.234    ([50.1095, 8.6785], 0.6000000000000001)
# 80.249.208.124                 ([52.3375, 4.9305], 0.597)
# 195.122.180.66                 ([48.2395, 8.7715], 0.729)
# 62.115.187.154   ([55.6115, 13.0105], 2.5380000000000003)
# ...                                                   ...
# 217.5.88.250                   ([50.1095, 8.6805], 21.92)
# 193.114.170.227                ([50.8805, 4.5015], 4.849)
# 196.25.245.150               ([-29.7295, 31.0875], 9.728)
# 46.59.112.142                 ([59.2775, 17.9815], 3.069)
# 172.16.189.54               ([32.7885, -96.7885], 58.357)
#
#                                             location  \
# 80.81.193.87     DE|Frankfurt am Main|50.1153,8.6823
# 87.186.181.234   DE|Frankfurt am Main|50.1112,8.6831
# 80.249.208.124           NL|Amsterdam|52.3740,4.8897
# 195.122.180.66   DE|Frankfurt am Main|50.1155,8.6842
# 62.115.187.154         DK|Copenhagen|55.6759,12.5655
# ...                                              ...
# 217.5.88.250                                    None
# 193.114.170.227            GB|London|51.5085,-0.1257
# 196.25.245.150                                  None
# 46.59.112.142           SE|Stockholm|59.3294,18.0687
# 172.16.189.54                                   None
#
#                                                     mapped_site
# 80.81.193.87            Frankfurt, Germany|50.1109221,8.6821267
# 87.186.181.234          Frankfurt, Germany|50.1109221,8.6821267
# 80.249.208.124      Amsterdam, Netherlands|52.3675734,4.9041389
# 195.122.180.66          Frankfurt, Germany|50.1109221,8.6821267
# 62.115.187.154        Copenhagen, Denmark|55.6760968,12.5683371
# ...                                                         ...
# 217.5.88.250                                               None
# 193.114.170.227    London, United Kingdom|51.5072178,-0.1275862
# 196.25.245.150                                             None
# 46.59.112.142    Stockholm, Sweden|59.32932349999999,18.0685808
# 172.16.189.54                                              None
#
# [249 rows x 7 columns]

# %%
phop_pd['location'] = phop_pd.apply(lambda x: extractDist(x), axis=1)

# %%
phop_pd = phop_pd[~pd.isna(phop_pd["location"])]

# %%
with open(f"../dataset/dc_lst/imperva.txt") as f:
    content = f.read()
    dc_lst = eval(content)

# %%
def DC_tracer(geo):
    try:
        curlat, curlon = geo.split('|')[-1].split(',')
        curlat, curlon = float(curlat), float(curlon)
        dist = []
        for each in dc_lst:   #dc:"lat,lon"
            for city, item in each.items():
                dclat, dclon = item.split(",")
                dclat, dclon = float(dclat), float(dclon)
                dist.append((great_circle((curlat,curlon),(dclat,dclon)).km, f"{city}|{item}"))     
        return sorted(dist)[0][1]                             #phop mapped to dc(city|geo)
    except:
        return None

# %%
try:
    print("mapping phop to the site...")
    phop_pd['mapped_site'] = phop_pd['location'].apply(lambda x:DC_tracer(x))
    mapping_dc_lst = phop_pd['mapped_site'].value_counts().index.to_list()                         #mapped site
    print(f"In total, using RIPE Atlas can resolve {len(mapping_dc_lst)} sites with {len(dc_lst)-len(mapping_dc_lst)} sites left unresolvable.")
except Exception as e:
    print(e)
    print("something error when mapping sites")
# Out:
# mapping phop to the site...
# In total, using RIPE Atlas can resolve 47 sites with 3 sites left unresolvable.

# %%
mapping_dc_lst
# Out:
# ['Newark, NJ, United States|40.735657,-74.1723667',
#  'London, United Kingdom|51.5072178,-0.1275862',
#  'Stockholm, Sweden|59.32932349999999,18.0685808',
#  'Paris, France|48.856614,2.3522219',
#  'Amsterdam, Netherlands|52.3675734,4.9041389',
#  'Sydney, NSW, Australia|-33.8688197,151.2092955',
#  'Ashburn, VA, United States|39.0437567,-77.4874416',
#  'Singapore, Singapore|1.352083,103.819836',
#  'Chicago, IL, United States|41.8781136,-87.6297982',
#  'Frankfurt, Germany|50.1109221,8.6821267',
#  'Johannesburg, South Africa|-26.2041028,28.0473051',
#  'Jakarta, Indonesia|-6.2087634,106.845599',
#  'Taipei, Taiwan|25.0329636,121.5654268',
#  'Tokyo, Japan|35.6761919,139.6503106',
#  'Copenhagen, Denmark|55.6760968,12.5683371',
#  'Madrid, Spain|40.4167754,-3.7037902',
#  'Istanbul, Turkey|41.0082376,28.9783589',
#  'Zürich, Switzerland|47.3768866,8.541694',
#  'Seattle, WA, United States|47.6062095,-122.3320708',
#  'Miami, FL, United States|25.7616798,-80.1917902',
#  'Vienna, Austria|48.2081743,16.3738189',
#  'Auckland, New Zealand|-36.85088270000001,174.7644881',
#  'Seoul, South Korea|37.566535,126.9779692',
#  'Santiago, Chile|-33.4488897,-70.6692655',
#  'Atlanta, GA, United States|33.7489954,-84.3879824',
#  'San Jose, CA, United States|37.33874,-121.8852525',
#  'Melbourne, VIC, Australia|-37.8136276,144.9630576',
#  'Warsaw, Poland|52.2296756,21.0122287',
#  'Osaka, Japan|34.6937249,135.5022535',
#  'Milan, Italy|45.4642035,9.189982',
#  'Mumbai, India|19.0759837,72.8776559',
#  'Tel Aviv, Israel|32.0852999,34.78176759999999',
#  'Hong Kong, Hong Kong|22.3193039,114.1693611',
#  'Vancouver, BC, Canada|49.2827291,-123.1207375',
#  'Bangkok, Thailand|13.7563309,100.5017651',
#  'Los Angeles, CA, United States|34.0522342,-118.2436849',
#  'Denver, CO, United States|39.7392358,-104.990251',
#  'Tultitlán, Mexico|19.6392125,-99.1668646',
#  'Dubai, United Arab Emirates|25.2048493,55.2707828',
#  'Dallas, TX, United States|32.7766642,-96.79698789999999',
#  'Toronto, ON, Canada|43.653226,-79.3831843',
#  'Buenos Aires, Argentina|-34.6036844,-58.3815591',
#  'Selangor, Malaysia|3.0738379,101.5183469',
#  'Cape Town, South Africa|-33.9248685,18.4240553',
#  'São Paulo, Brazil|-23.5557714,-46.6395571',
#  'New Delhi, India|28.6139391,77.2090212',
#  'Dublin, Ireland|53.3498053,-6.2603097']

# %%
import subprocess
def check_ip_ping(ip):
    p = subprocess.Popen(['bash','ping.sh',ip],stdout=subprocess.PIPE)
    result = p.stdout.read()
    print(result)
    if result == b'1\n':
        return False
    else:
        return True

# %%
def bogonip(ip):
    bogon_ip_range=["0.0.0.0/8","10.0.0.0/8","100.64.0.0/10","127.0.0.0/8","127.0.53.53","169.254.0.0/16","172.16.0.0/12","192.0.0.0/24","192.0.2.0/24","192.168.0.0/16","198.18.0.0/15","198.51.100.0/24","203.0.113.0/24","224.0.0.0/4","240.0.0.0/4","255.255.255.255/32"]
    for ran in bogon_ip_range:
        if ip in IP(ran):
            return True
    return False

# %%
bogonip("192.168.100.1")
# Out:
# True

# %%
repr_phop = {}
for _, phop in phop_pd.iterrows():
    if phop['location'] != None:
        phop_lat, phop_lon = phop['location'].split('|')[-1].split(',')
        site_lat, site_lon = phop['mapped_site'].split('|')[-1].split(',')
        mapped_site = phop['mapped_site'].split('|')[0]
        if mapped_site not in repr_phop:
            if great_circle((phop_lat, phop_lon),(site_lat,site_lon)).km < 600 and check_ip_ping(phop.name) and not bogonip(phop.name):
                repr_phop[mapped_site] = [phop.name,great_circle((phop_lat, phop_lon),(site_lat,site_lon)).km]
        else:
            if great_circle((phop_lat, phop_lon),(site_lat,site_lon)).km < repr_phop[mapped_site][1] and check_ip_ping(phop.name) and not bogonip(phop.name):
                repr_phop[mapped_site] = [phop.name,great_circle((phop_lat, phop_lon),(site_lat,site_lon)).km]
print(f"In total, we can find {len(repr_phop)} sites' unicast representitives.")
# Out:
# b'0\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'1\n'
# b'0\n'
# b'1\n'
# b'0\n'
# b'0\n'
# b'1\n'
# b'0\n'
# In total, we can find 34 sites' unicast representitives.

# %%
check_ip_ping("80.249.208.124")
# Out:
# b'1\n'
# False

# %%
repr_phop
# Out:
# {'Frankfurt, Germany': ['87.186.181.234', 0.07597379521776958],
#  'Copenhagen, Denmark': ['62.115.187.154', 0.1792265672168534],
#  'Amsterdam, Netherlands': ['128.241.13.242', 1.213081739994957],
#  'San Jose, CA, United States': ['107.154.13.242', 37.7022867076859],
#  'Dublin, Ireland': ['185.6.36.156', 2.006052377380223],
#  'Chicago, IL, United States': ['75.149.230.98', 3.949495952065342],
#  'Ashburn, VA, United States': ['128.241.13.106', 13.500667413477329],
#  'Johannesburg, South Africa': ['41.60.135.61', 0.42050752473939407],
#  'Mumbai, India': ['182.79.186.90', 0.6287150618292764],
#  'London, United Kingdom': ['217.169.1.17', 5.290344164414355],
#  'Madrid, Spain': ['193.149.1.87', 0.10531113927454024],
#  'Miami, FL, United States': ['107.154.8.242', 1.4162756769466784],
#  'Vienna, Austria': ['128.241.13.250', 0.1324243274325263],
#  'Tokyo, Japan': ['63.216.242.138', 9.574714410783661],
#  'New Delhi, India': ['182.79.186.74', 4.7571429973126245],
#  'Sydney, NSW, Australia': ['210.10.203.2', 0.8563531576404114],
#  'Tel Aviv, Israel': ['84.110.104.138', 0.5014614723221125],
#  'Stockholm, Sweden': ['46.59.112.142', 0.01086609756980559],
#  'Singapore, Singapore': ['63.218.229.170', 7.7094860948957855],
#  'Seoul, South Korea': ['121.78.89.186', 0.07057418535517544],
#  'Hong Kong, Hong Kong': ['123.255.90.82', 4.592397210895934],
#  'Santiago, Chile': ['107.154.222.242', 2.139304668057493],
#  'Melbourne, VIC, Australia': ['58.163.93.118', 4.044834212339766],
#  'Buenos Aires, Argentina': ['8.243.136.186', 1.1204008308931392],
#  'Cape Town, South Africa': ['196.250.236.139', 0.13021529329963266],
#  'Auckland, New Zealand': ['180.235.105.165', 0.27915167413638625],
#  'Istanbul, Turkey': ['46.40.68.1', 504.44697592756165],
#  'Dubai, United Arab Emirates': ['185.23.196.245', 14.713987493932574],
#  'Atlanta, GA, United States': ['107.154.15.242', 0.0017057304700080758],
#  'Seattle, WA, United States': ['107.154.14.242', 0.002430673572222127],
#  'Paris, France': ['5.10.135.250', 0.4363473163022919],
#  'Newark, NJ, United States': ['192.168.100.1', 25.820162693410474],
#  'Taipei, Taiwan': ['63.218.247.18', 5.860356037400496],
#  'Zürich, Switzerland': ['212.25.27.124', 1.2939258860244767]}

# %%
mapping_dc_lst
# Out:
# ['Newark, NJ, United States|40.735657,-74.1723667',
#  'London, United Kingdom|51.5072178,-0.1275862',
#  'Stockholm, Sweden|59.32932349999999,18.0685808',
#  'Paris, France|48.856614,2.3522219',
#  'Amsterdam, Netherlands|52.3675734,4.9041389',
#  'Sydney, NSW, Australia|-33.8688197,151.2092955',
#  'Ashburn, VA, United States|39.0437567,-77.4874416',
#  'Singapore, Singapore|1.352083,103.819836',
#  'Chicago, IL, United States|41.8781136,-87.6297982',
#  'Frankfurt, Germany|50.1109221,8.6821267',
#  'Johannesburg, South Africa|-26.2041028,28.0473051',
#  'Jakarta, Indonesia|-6.2087634,106.845599',
#  'Taipei, Taiwan|25.0329636,121.5654268',
#  'Tokyo, Japan|35.6761919,139.6503106',
#  'Copenhagen, Denmark|55.6760968,12.5683371',
#  'Madrid, Spain|40.4167754,-3.7037902',
#  'Istanbul, Turkey|41.0082376,28.9783589',
#  'Zürich, Switzerland|47.3768866,8.541694',
#  'Seattle, WA, United States|47.6062095,-122.3320708',
#  'Miami, FL, United States|25.7616798,-80.1917902',
#  'Vienna, Austria|48.2081743,16.3738189',
#  'Auckland, New Zealand|-36.85088270000001,174.7644881',
#  'Seoul, South Korea|37.566535,126.9779692',
#  'Santiago, Chile|-33.4488897,-70.6692655',
#  'Atlanta, GA, United States|33.7489954,-84.3879824',
#  'San Jose, CA, United States|37.33874,-121.8852525',
#  'Melbourne, VIC, Australia|-37.8136276,144.9630576',
#  'Warsaw, Poland|52.2296756,21.0122287',
#  'Osaka, Japan|34.6937249,135.5022535',
#  'Milan, Italy|45.4642035,9.189982',
#  'Mumbai, India|19.0759837,72.8776559',
#  'Tel Aviv, Israel|32.0852999,34.78176759999999',
#  'Hong Kong, Hong Kong|22.3193039,114.1693611',
#  'Vancouver, BC, Canada|49.2827291,-123.1207375',
#  'Bangkok, Thailand|13.7563309,100.5017651',
#  'Los Angeles, CA, United States|34.0522342,-118.2436849',
#  'Denver, CO, United States|39.7392358,-104.990251',
#  'Tultitlán, Mexico|19.6392125,-99.1668646',
#  'Dubai, United Arab Emirates|25.2048493,55.2707828',
#  'Dallas, TX, United States|32.7766642,-96.79698789999999',
#  'Toronto, ON, Canada|43.653226,-79.3831843',
#  'Buenos Aires, Argentina|-34.6036844,-58.3815591',
#  'Selangor, Malaysia|3.0738379,101.5183469',
#  'Cape Town, South Africa|-33.9248685,18.4240553',
#  'São Paulo, Brazil|-23.5557714,-46.6395571',
#  'New Delhi, India|28.6139391,77.2090212',
#  'Dublin, Ireland|53.3498053,-6.2603097']

# %%
def siteRank(data):
    try:
        dis = great_circle((data["mapped_site"].split("|")[1].split(",")[0], data["mapped_site"].split("|")[1].split(",")[1]), (data['lat'],data['lon'])).km
        rank = 0
        for site in mapping_dc_lst:
            if dis > great_circle((site.split("|")[1].split(",")[0], site.split("|")[1].split(",")[1]), (data['lat'],data['lon'])).km:
                rank += 1
        return rank
    except:
        return None

# %%
measure_pd = measure_pd.merge(phop_pd[["mapped_site"]],left_on="p_hop",right_index=True)
measure_pd = measure_pd.merge(valid_probe_pd[['id','location']],left_on="prb_id",right_on="id")
measure_pd['lat'] = measure_pd['location'].str[1]
measure_pd['lon'] = measure_pd['location'].str[0]

# %%
measure_pd
# Out:
#       index    fw   mver  lts     endtime        dst_name         ttr  \
# 0         0  5040  2.4.1   -1  1661405722  www.stamps.com  205.282194
# 1        46  5040  2.4.1   25  1661406007  www.stamps.com    5.579309
# 2        60  5040  2.4.1   50  1661406006  www.stamps.com  337.688534
# 3       135  4790    NaN   37  1661405997  www.stamps.com         NaN
# 4       199  4790    NaN  127  1661405991  www.stamps.com         NaN
# ...     ...   ...    ...  ...         ...             ...         ...
# 7232    904  5070  2.6.1   30  1661406122  www.stamps.com   60.186155
# 7233    785  5070  2.6.1   21  1661406009  www.stamps.com    9.444458
# 7234    850  5070  2.6.1   49  1661406019  www.stamps.com  280.210292
# 7235    625  5070  2.6.1   37  1661406020  www.stamps.com   73.198124
# 7236    862  5070  2.6.1   27  1661406000  www.stamps.com  359.439157
#
#           dst_addr        src_addr proto  ...           p_hop     rtt   p_rtt  \
# 0     45.60.155.44      172.17.0.2  ICMP  ...   212.133.7.122   8.860   9.281
# 1     45.60.155.44      172.17.0.3  ICMP  ...   212.133.7.122   4.588   4.590
# 2     45.60.155.44  192.168.178.48  ICMP  ...   212.133.7.122  21.842  22.021
# 3     45.60.155.44     192.168.1.3  ICMP  ...   212.133.7.122  22.205  20.379
# 4     45.60.155.44     31.170.10.7  ICMP  ...   212.133.7.122  12.671   9.296
# ...            ...             ...   ...  ...             ...     ...     ...
# 7232  45.60.155.44      172.16.0.2  ICMP  ...   82.166.97.196   4.363   4.939
# 7233  45.60.155.44  192.168.50.239  ICMP  ...     2.120.13.87   9.257   9.547
# 7234  45.60.155.44  192.168.100.55  ICMP  ...  31.223.122.185   3.726   5.823
# 7235  45.60.155.44      10.0.6.173  ICMP  ...   212.25.27.124   7.615   2.605
# 7236  45.60.151.44    192.168.2.12  ICMP  ...     192.168.2.1   2.288   0.329
#
#           lat      lon                                      mapped_site  \
# 0     45.4505  11.0605                 Milan, Italy|45.4642035,9.189982
# 1     45.4695  11.0405                 Milan, Italy|45.4642035,9.189982
# 2     42.0215  14.5475                 Milan, Italy|45.4642035,9.189982
# 3     41.8995  12.4375                 Milan, Italy|45.4642035,9.189982
# 4     43.3075   5.3905                 Milan, Italy|45.4642035,9.189982
# ...       ...      ...                                              ...
# 7232  31.9615  34.8085    Tel Aviv, Israel|32.0852999,34.78176759999999
# 7233  52.2585  -1.5425                                             None
# 7234  41.1505  27.8215           Istanbul, Turkey|41.0082376,28.9783589
# 7235  47.4895   8.6975          Zürich, Switzerland|47.3768866,8.541694
# 7236  42.8185 -74.0085  Newark, NJ, United States|40.735657,-74.1723667
#
#            id             location site_rank  \
# 0     1003476   [11.0605, 45.4505]       0.0
# 1     1003474   [11.0405, 45.4695]       0.0
# 2     1003519   [14.5475, 42.0215]       0.0
# 3          14   [12.4375, 41.8995]       0.0
# 4        2261    [5.3905, 43.3075]       0.0
# ...       ...                  ...       ...
# 7232    25838   [34.8085, 31.9615]       0.0
# 7233    55302   [-1.5425, 52.2585]       NaN
# 7234    55696   [27.8215, 41.1505]       0.0
# 7235    30104    [8.6975, 47.4895]       0.0
# 7236    32592  [-74.0085, 42.8185]       0.0
#
#                                                clsthree
# 0     [Milan, Italy, Zürich, Switzerland, Vienna, Au...
# 1     [Milan, Italy, Zürich, Switzerland, Vienna, Au...
# 2     [Milan, Italy, Vienna, Austria, Zürich, Switze...
# 3     [Milan, Italy, Zürich, Switzerland, Vienna, Au...
# 4     [Milan, Italy, Zürich, Switzerland, Paris, Fra...
# ...                                                 ...
# 7232  [Tel Aviv, Israel, Istanbul, Turkey, Dubai, Un...
# 7233  [London, United Kingdom, Dublin, Ireland, Amst...
# 7234  [Istanbul, Turkey, Tel Aviv, Israel, Vienna, A...
# 7235  [Zürich, Switzerland, Milan, Italy, Frankfurt,...
# 7236  [Newark, NJ, United States, Toronto, ON, Canad...
#
# [7237 rows x 33 columns]

# %%
measure_pd.drop(columns=["mapped_site_x","id_x","location_x","mapped_site_y","id_y","location_y"],inplace=True)

# %%
measure_pd['site_rank'] = measure_pd.apply(lambda x: siteRank(x), axis=1)

# %%
measure_pd['site_rank'].value_counts().tail(5)
# Out:
# 35.0    1
# 33.0    1
# 40.0    1
# 23.0    1
# 30.0    1
# Name: site_rank, dtype: int64

# %%
def topthree(data):         # select three closest sites
    dis_dict = {}
    for site in mapping_dc_lst:
        dis_dict[site] = great_circle((site.split("|")[1].split(",")[0], site.split("|")[1].split(",")[1]), (data['lat'],data['lon'])).km
    dis_dict = sorted(dis_dict.items(),key=lambda x:x[1])
    return [x[0].split("|")[0] for x in dis_dict[0:3]]

# %%
measure_pd["clsthree"] = measure_pd.apply(lambda x: topthree(x), axis=1)

# %%
measure_dict = {}
for _, item in measure_pd.iterrows():
    for site in item["clsthree"]:
        if site in repr_phop.keys():
            if repr_phop[site][0] not in measure_dict.keys():
                measure_dict[repr_phop[site][0]] = [item['prb_id']]
            else:
                measure_dict[repr_phop[site][0]].append(item['prb_id'])

# %%
measure_dict
# Out:
# {'212.25.27.124': [1003476,
#   1003474,
#   1003519,
#   14,
#   2261,
#   2330,
#   34506,
#   35461,
#   853,
#   912,
#   1004092,
#   6329,
#   1004427,
#   13659,
#   13902,
#   15458,
#   1001501,
#   1000791,
#   1001421,
#   1001592,
#   19848,
#   51973,
#   52113,
#   53383,
#   1003666,
#   1003943,
#   53571,
#   21274,
#   21932,
#   22074,
#   54869,
#   54949,
#   55071,
#   55227,
#   21472,
#   22144,
#   22296,
#   25035,
#   25034,
#   26231,
#   27040,
#   55405,
#   55447,
#   28347,
#   28386,
#   28483,
#   30770,
#   31667,
#   32679,
#   34965,
#   16286,
#   2027,
#   2196,
#   2326,
#   248,
#   2697,
#   32941,
#   33356,
#   33444,
#   33445,
#   33580,
#   33871,
#   33886,
#   33980,
#   34003,
#   34010,
#   34752,
#   34933,
#   549,
#   619,
#   706,
#   850,
#   938,
#   2777,
#   2916,
#   3156,
#   3327,
#   3333,
#   3395,
#   4259,
#   4799,
#   4873,
#   6272,
#   4320,
#   6724,
#   10826,
#   11177,
#   12177,
#   7040,
#   10864,
#   10920,
#   1000196,
#   1000336,
#   1000506,
#   14525,
#   14719,
#   14894,
#   15128,
#   15143,
#   15146,
#   15921,
#   16693,
#   17250,
#   13415,
#   14618,
#   16061,
#   16505,
#   50048,
#   1001405,
#   18089,
#   50445,
#   50747,
#   50763,
#   51024,
#   51168,
#   51456,
#   1001169,
#   1001325,
#   50884,
#   50918,
#   50955,
#   1002001,
#   1002231,
#   1002477,
#   1002774,
#   1002829,
#   18931,
#   19615,
#   52033,
#   52279,
#   52514,
#   52701,
#   52712,
#   20605,
#   52779,
#   52995,
#   53053,
#   53265,
#   53310,
#   53333,
#   53489,
#   53674,
#   1003349,
#   1003399,
#   20118,
#   20250,
#   52758,
#   52766,
#   53179,
#   53219,
#   53254,
#   53363,
#   53485,
#   52819,
#   21416,
#   21954,
#   21996,
#   22098,
#   22427,
#   22455,
#   53806,
#   53986,
#   54061,
#   54068,
#   54378,
#   55024,
#   55064,
#   22377,
#   54263,
#   54621,
#   54953,
#   24539,
#   26065,
#   26821,
#   26894,
#   27219,
#   55384,
#   24906,
#   25341,
#   26590,
#   26755,
#   27280,
#   27668,
#   27740,
#   55254,
#   55331,
#   55834,
#   28726,
#   29325,
#   29345,
#   29639,
#   29701,
#   29736,
#   29951,
#   30644,
#   30717,
#   30957,
#   30958,
#   31056,
#   31191,
#   31966,

#   1002216,
#   1002216,
#   1002216,
#   1002216,
#   1002216,
#   1002216,
#   1002216,
#   1002216,
#   1002224,
#   1002290,
#   1002317,
#   1002486,
#   1002487,
#   1002776,
#   1002930,
#   18822,
#   19798,
#   52132,
#   52154,
#   52292,
#   52339,
#   52543,
#   52548,
#   52723,
#   18777,
#   18965,
#   19258,
#   19343,
#   19434,
#   19474,
#   51842,
#   52301,
#   52681,
#   52690,
#   52720,
#   20004,
#   20015,
#   20338,
#   20567,
#   20973,
#   52802,
#   52821,
#   52901,
#   53499,
#   53557,
#   53723,
#   1003396,
#   1004014,
#   52782,
#   52999,
#   53437,
#   1004003,
#   20128,
#   1000811,
#   1000812,
#   1004141,
#   1004199,
#   1004355,
#   21233,
#   21236,
#   21277,
#   21750,
#   21956,
#   22101,
#   22131,
#   22294,
#   22441,
#   53801,
#   53850,
#   54876,
#   54989,
#   55074,
#   55120,
#   55232,
#   22072,
#   22364,
#   53809,
#   53857,
#   54189,
#   54249,
#   54437,
#   55061,
#   55138,
#   55241,
#   23392,
#   23835,
#   24196,
#   24490,
#   25362,
#   26291,
#   26353,
#   26465,
#   27640,
#   55489,
#   1001449,
#   1001602,
#   22507,
#   22642,
#   22945,
#   22980,
#   24032,
#   24089,
#   24371,
#   24957,
#   26385,
#   27992,
#   55481,
#   55529,
#   28797,
#   28891,
#   29455,
#   29535,
#   29662,
#   30673,
#   30768,
#   32111,
#   32175,
#   32271,
#   32703,
#   32715,
#   28284,
#   28698,
#   28774,
#   29341,
#   29596,
#   29751,
#   29790,
#   30134,
#   30144,
#   30605,
#   31061,
#   31554,
#   31651,
#   31849,
#   1003493,
#   1324,
#   1493,
#   2758,
#   33242,
#   33746,
#   33773,
#   605,
#   651,
#   1004016,
#   2847,
#   2873,
#   3104,
#   3441,
#   35605,
#   4242,
#   4539,
#   6680,
#   6741,
#   3668,
#   6510,
#   1004448,
#   10281,
#   11586,
#   11590,
#   11649,
#   11737,
#   12370,
#   12462,
#   6812,
#   6838,
#   7008,
#   7013,
#   11433,
#   11440,
#   1000093,
#   1000125,
#   1000127,
#   1000152,
#   1000261,
#   1000395,
#   1000467,
#   1000485,
#   13200,
#   14899,
#   16135,
#   16288,
#   16329,
#   16751,
#   50243,
#   1001208,
#   18433,
#   1001351,
#   1001563,
#   17931,
#   18085,
#   50285,
#   50864,
#   50898,
#   1001965,
#   1002453,
#   1002810,
#   19423,
#   19664,
#   19667,
#   20127,
#   20582,
#   20709,
#   52748,
#   52836,
#   53293,
#   53435,
#   1003111,
#   1003815,
#   1003922,
#   1003956,
#   20985,
#   52827,
#   53050,
#   53158,
#   53238,
#   20716,
#   1004101,
#   1004237,
#   21360,
#   21452,
#   21998,
#   22392,
#   22424,
#   53810,
#   53811,
#   53886,
#   53983,
#   54041,
#   21283,
#   53815,
#   54371,
#   54645,
#   54704,
#   24501,
#   27936,
#   23232,
#   25484,
#   25646,
#   26624,
#   55378,
#   55593,
#   26261,
#   27804,
#   29640,
#   31949,
#   29720,
#   29740,
#   29754,
#   31065,
#   1205,
#   1357,
#   6438,
#   14628,
#   50354,
#   18817,
#   18859,
#   51735,
#   52040,
#   52954,
#   1003553,
#   20073,
#   22467,
#   122,
#   218,
#   589,
#   764,
#   1003816,
#   2764,
#   35603,
#   3742,
#   4779,
#   4925,
#   6276,
#   6327,
#   6788,
#   6042,
#   6334,
#   10113,
#   11110,
#   11125,
#   11163,
#   11225,
#   11237,
#   11240,
#   11241,
#   11254,
#   11723,
#   6810,
#   6827,
#   7046,
#   11226,
#   11244,
#   13542,
#   13593,
#   13775,
#   1001622,
#   50287,
#   50535,
#   50691,
#   51514,
#   1000654,
#   1000767,
#   1001187,
#   50530,
#   1002051,
#   1002199,
#   19690,
#   52570,
#   52598,
#   52711,
#   19840,
#   51873,
#   52683,
#   20170,
#   53192,
#   1000618,
#   1003317,
#   20430,
#   52788,
#   52992,
#   53367,
#   53775,
#   52777,
#   1004262,
#   1004544,
#   22450,
#   53968,
#   54115,
#   54767,
#   21408,
#   21434,
#   54460,
#   22568,
#   25965,
#   55750,
#   25436,
#   25714,
#   25746,
#   27478,
#   28088,
#   28614,
#   28769,
#   28961,
#   30012,
#   32254,
#   28110,
#   28583,
#   29909,
#   30923,
#   30948,
#   1251,
#   1002662,
#   23434,
#   33106,
#   33735,
#   34097,
#   33783,
#   4712,
#   12792,
#   12980,
#   1000082,
#   1000797,
#   50504,
#   1001487,
#   54804,
#   21554,
#   23308,
#   55704,
#   25718,
#   60065,
#   23450,
#   1002834,
#   28055,
#   29977,
#   31346,
#   32669,
#   2626,
#   895,
#   33681,
#   2816,
#   2944,
#   3062,
#   3263,
#   3467,
#   35529,
#   3695,
#   3963,
#   4101,
#   4105,
#   6304,
#   6402,
#   1004345,
#   10100,
#   1000035,
#   1000032,
#   1000067,
#   1000071,
#   1000198,
#   1000253,
#   15651,
#   16212,
#   16302,
#   16657,
#   16715,
#   13975,
#   1000661,
#   18138,
#   18566,
#   50644,
#   51493,
#   1000590,
#   1000989,
#   1001365,
#   1001538,
#   1001597,
#   1002153,
#   1002658,
#   1002758,
#   18948,
#   19384,
#   52129,
#   52010,
#   53025,
#   53167,
#   53791,
#   1003257,
#   1003402,
#   1003465,
#   1003468,
#   1003607,
#   1003672,
#   1003923,
#   20713,
#   53200,
#   21973,
#   22258,
#   25785,
#   26178,
#   25742,
#   26634,
#   27256,
#   30041,
#   29746,
#   28739,
#   32768,
#   712,
#   12280,
#   14769,
#   50604,
#   1001767,
#   18350,
#   19010,
#   19847,
#   52364,
#   1003473,
#   1004027,
#   53017,
#   21265,
#   21468,
#   22003,
#   54632,
#   55183,
#   27297,
#   23345,
#   26942,
#   55560,
#   1002919,
#   31603,
#   1469,
#   4216,
#   4528,
#   4809,
#   4848,
#   6577,
#   6619,
#   6686,
#   11518,
#   12179,
#   14829,
#   18696,
#   18766,
#   51299,
#   1001595,
#   1001742,
#   1001769,
#   18554,
#   50331,
#   19242,
#   52312,
#   1004019,
#   1003177,
#   22106,
#   54604,
#   25462,
#   30425,
#   31936,
#   6323,
#   19121,
#   27323,
#   32689,
#   1367,
#   34817,
#   2942,
#   4956,
#   6325,
#   6417,
#   11219,
#   16204,
#   13291,
#   50341,
#   19473,
#   21679,
#   21783,
#   60089,
#   2309,
#   33737,
#   33742,
#   33748,
#   34168,
#   422,
#   1004058,
#   2988,
#   4029,
#   10176,
#   13315,
#   13738,
#   16336,
#   1000630,
#   51037,
#   19291,
#   ...],
#  '5.10.135.250': [2261,
#   35461,
#   50608,
#   51973,
#   30910,
#   2355,
#   34001,
#   818,
#   3110,
#   4982,
#   6405,
#   6695,
#   10501,
#   10735,
#   10860,
#   11525,
#   11587,
#   11633,
#   11702,
#   11802,
#   11835,
#   11939,
#   12076,
#   12321,
#   12796,
#   6937,
#   10022,
#   10806,
#   11499,
#   7101,
#   11576,
#   12356,
#   1000457,
#   13665,
#   13745,
#   13892,
#   14577,
#   14983,
#   15018,
#   15324,
#   15838,
#   16233,
#   16395,
#   14616,
#   14647,
#   16130,
#   50012,
#   14934,
#   1000928,
#   1000944,
#   1001354,
#   18655,
#   1002183,
#   1002545,
#   1002787,
#   52675,
#   20003,
#   20180,
#   53031,
#   20189,
#   52778,
#   53496,
#   53518,
#   54438,
#   54959,
#   21508,
#   55653,
#   22959,
#   24550,
#   55735,
#   28890,
#   1002994,
#   1002995,
#   1003021,
#   1003026,
#   1003037,
#   2234,
#   2477,
#   33426,
#   33542,
#   34484,
#   34753,
#   35083,
#   326,
#   3178,
#   4873,
#   6648,
#   3128,
#   7051,
#   11124,
#   1000249,
#   1000422,
#   1000430,
#   1000431,
#   1000438,
#   16665,
#   1000998,
#   1001043,
#   1001066,
#   1001264,
#   1001369,
#   1001668,
#   1001669,
#   1001675,
#   1001708,
#   1001720,
#   1001727,
#   1001728,
#   18089,
#   18113,
#   50631,
#   50659,
#   50715,
#   51022,
#   1001012,
#   1001047,
#   1001072,
#   1001333,
#   1001540,
#   1001683,
#   1001696,
#   1001702,
#   1001705,
#   1001722,
#   1001763,
#   1002992,
#   1000434,
#   1001828,
#   1001841,
#   1001847,
#   1001849,
#   1001852,
#   1001919,
#   1001920,
#   1001922,
#   1001927,
#   1001928,
#   1001934,
#   1001976,
#   1001981,
#   1002052,
#   1002054,
#   1002063,
#   1002233,
#   1002401,
#   1002403,
#   1002991,
#   52516,
#   1003019,
#   1003009,
#   20471,
#   20499,
#   1002997,
#   1003004,
#   1003008,
#   1003020,
#   1003028,
#   1003030,
#   1003031,
#   1003032,
#   1003874,
#   1004043,
#   1004118,
#   21280,
#   21308,
#   54938,
#   27199,
#   55264,
#   24886,
#   25438,
#   29221,
#   32274,
#   28582,
#   29962,
#   32589,
#   2597,
#   3170,
#   11917,
#   12071,
#   12341,
#   13308,
#   17997,
#   1001188,
#   50760,
#   19560,
#   1004243,
#   54522,
#   24345,
#   26497,
#   24434,
#   1003045,
#   23254,
#   26072,
#   55641,
#   55718,
#   22958,
#   23290,
#   23333,
#   24470,
#   25323,
#   26467,
#   26754,
#   27642,
#   55537,
#   26108,
#   28332,
#   28416,
#   30402,
#   30771,
#   31148,
#   31963,
#   32106,
#   32764,
#   1002698,
#   1002979,
#   28318,
#   28922,
#   29175,
#   29187,
#   29339,
#   30951,
#   31521,
#   31556,
#   32016,
#   32317,
#   32608,
#   29438,
#   6260,
#   6513,
#   6666,
#   6668,
#   6817,
#   6830,
#   12344,
#   16100,
#   51137,
#   1002104,
#   52969,
#   53580,
#   20538,
#   53456,
#   53661,
#   21271,
#   21570,
#   23318,
#   29333,
#   29823,
#   28412,
#   29491,
#   30704,
#   32126,
#   27388,
#   1003375,
#   2220,
#   2246,
#   2434,
#   33822,
#   33950,
#   34598,
#   34878,
#   35202,
#   33991,
#   35512,
#   1003984,
#   3310,
#   4306,
#   4649,
#   6213,
#   6249,
#   6310,
#   6576,
#   6589,
#   4796,
#   6443,
#   6642,
#   10061,
#   10214,
#   11272,
#   11323,
#   11434,
#   11663,
#   11703,
#   11900,
#   12211,
#   6814,
#   6816,
#   6846,
#   6874,
#   6919,
#   7004,
#   7006,
#   7035,
#   7068,
#   11667,
#   7122,
#   1000170,
#   13002,
#   13005,
#   13008,
#   13430,
#   15809,
#   16297,
#   13267,
#   1000546,
#   1000948,
#   50660,
#   50725,
#   1000678,
#   18348,
#   18378,
#   51313,
#   1002258,
#   1002857,
#   1002938,
#   19468,
#   19486,
#   52371,
#   52538,
#   52669,
#   52673,
#   53215,
#   53215,
#   53215,
#   53215,
#   53215,
#   53215,
#   53215,
#   53215,
#   53232,
#   53273,
#   1003472,
#   1003983,
#   1003985,
#   53047,
#   53187,
#   1004545,
#   21385,
#   21727,
#   22115,
#   54076,
#   54759,
#   54007,
#   54714,
#   24400,
#   24544,
#   24903,
#   24982,
#   26255,
#   22873,
#   24114,
#   24288,
#   26124,
#   23191,
#   29248,
#   29399,
#   29405,
#   30573,
#   30746,
#   30919,
#   32067,
#   32089,
#   32420,
#   32499,
#   28934,
#   29610,
#   29655,
#   29753,
#   30974,
#   31504,
#   32553,
#   32751,
#   31833,
#   1003433,
#   1338,
#   1419,
#   33476,
#   33812,
#   34696,
#   35441,
#   4943,
#   11722,
#   6858,
#   1000339,
#   14111,
#   17110,
#   51087,
#   51204,
#   1000596,
#   1000693,
#   1001142,
#   53297,
#   53337,
#   1003477,
#   1003911,
#   52980,
#   53570,
#   53646,
#   1004167,
#   21292,
#   21347,
#   22378,
#   54780,
#   54878,
#   21339,
#   53872,
#   26722,
#   27376,
#   27619,
#   55365,
#   55643,
#   26732,
#   55705,
#   23165,
#   24970,
#   28125,
#   29213,
#   29219,
#   29227,
#   29389,
#   29682,
#   29717,
#   30990,
#   31503,
#   32729,
#   31741,
#   14814,
#   1003509,
#   1003511,
#   2553,
#   33241,
#   34004,
#   35457,
#   986,
#   2783,
#   6501,
#   12014,
#   12438,
#   6847,
#   7120,
#   11531,
#   12774,
#   28349,
#   32284,
#   1226,
#   1252,
#   1320,
#   197,
#   2181,
#   2273,
#   2624,
#   33396,
#   33631,
#   33818,
#   34429,
#   34541,
#   34981,
#   35433,
#   439,
#   33869,
#   2445,
#   1003768,
#   1004067,
#   1004085,
#   3282,
#   3351,
#   3560,
#   6518,
#   11733,
#   11790,
#   11828,
#   12142,
#   12349,
#   12829,
#   6980,
#   1000316,
#   1000449,
#   13050,
#   13230,
#   13414,
#   13467,
#   13471,
#   14035,
#   14043,
#   14049,
#   14631,
#   16020,
#   16146,
#   16991,
#   17030,
#   17055,
#   17065,
#   17151,
#   17174,
#   17230,
#   17242,
#   13039,
#   13680,
#   13911,
#   14520,
#   15845,
#   15873,
#   15973,
#   17032,
#   17131,
#   13881,
#   ...],
#  '87.186.181.234': [6329,
#   15458,
#   1001501,
#   1000791,
#   52113,
#   1003943,
#   53571,
#   21932,
#   54869,
#   55071,
#   21472,
#   25035,
#   28347,
#   30770,
#   1,
#   1003292,
#   2355,
#   34001,
#   34099,
#   34965,
#   67,
#   910,
#   1003681,
#   1003747,
#   3110,
#   3274,
#   4008,
#   4286,
#   4501,
#   4604,
#   6400,
#   10001,
#   10015,
#   1004472,
#   11633,
#   11713,
#   11717,
#   11863,
#   11939,
#   12321,
#   6937,
#   10022,
#   11815,
#   1000301,
#   13358,
#   13476,
#   13649,
#   13892,
#   14983,
#   15018,
#   16233,
#   16395,
#   14616,
#   15793,
#   16286,
#   50012,
#   1000577,
#   1001131,
#   50729,
#   1000928,
#   1001354,
#   18418,
#   51186,
#   1002545,
#   1002814,
#   20003,
#   20180,
#   52824,
#   52972,
#   53244,
#   53721,
#   1003158,
#   52846,
#   53002,
#   53518,
#   53749,
#   21364,
#   22344,
#   54291,
#   54300,
#   55143,
#   24004,
#   27673,
#   55653,
#   22890,
#   27793,
#   28498,
#   31046,
#   31275,
#   31916,
#   32430,
#   28890,
#   28956,
#   29304,
#   31721,
#   31861,
#   32075,
#   28729,
#   28729,
#   28729,
#   28729,
#   28729,
#   28729,
#   28729,
#   28729,
#   28740,
#   29368,
#   29377,
#   1003046,
#   1477,
#   159,
#   2196,
#   2326,
#   2477,
#   32941,
#   32965,
#   33356,
#   33426,
#   33444,
#   33445,
#   33518,
#   33524,
#   33542,
#   33580,
#   33598,
#   33622,
#   33833,
#   33871,
#   33886,
#   33896,
#   33980,
#   34003,
#   34442,
#   34484,
#   34495,
#   34612,
#   34752,
#   34753,
#   34933,
#   35083,
#   706,
#   823,
#   850,
#   905,
#   326,
#   33889,
#   1003678,
#   2777,
#   3156,
#   3327,
#   3333,
#   35528,
#   4259,
#   4799,
#   4873,
#   6272,
#   3128,
#   3294,
#   6724,
#   10826,
#   11075,
#   11177,
#   11824,
#   12028,
#   12177,
#   7075,
#   7096,
#   10864,
#   10920,
#   1000196,
#   1000249,
#   1000336,
#   1000506,
#   13201,
#   14149,
#   14525,
#   14719,
#   14894,
#   15128,
#   15143,
#   15146,
#   15921,
#   16152,
#   16665,
#   16693,
#   1003048,
#   1003804,
#   3657,
#   10249,
#   10274,
#   12597,
#   12873,
#   1001553,
#   51001,
#   1001963,
#   1001964,
#   1002156,
#   53069,
#   20727,
#   53412,
#   1000938,
#   21227,
#   21566,
#   21662,
#   21799,
#   53969,
#   54452,
#   54627,
#   54688,
#   54746,
#   55090,
#   55166,
#   22937,
#   55348,
#   55731,
#   25203,
#   27588,
#   55274,
#   55804,
#   55846,
#   28137,
#   29074,
#   1528,
#   13370,
#   33920,
#   12992,
#   6841,
#   13010,
#   19306,
#   27903,
#   28119,
#   7090,
#   12454,
#   12832,
#   1001488,
#   19302,
#   1002909,
#   20461,
#   20649,
#   1003671,
#   26113,
#   28002,
#   30977,
#   10972,
#   1002729,
#   1003588,
#   1211,
#   2161,
#   2198,
#   2496,
#   33780,
#   34411,
#   34602,
#   34679,
#   34715,
#   35275,
#   35462,
#   563,
#   714,
#   32955,
#   1004017,
#   2905,
#   2968,
#   2970,
#   2981,
#   35643,
#   35708,
#   3659,
#   3749,
#   3944,
#   3953,
#   4158,
#   4389,
#   4468,
#   4500,
#   4861,
#   6326,
#   6475,
#   6603,
#   4594,
#   6295,
#   6453,
#   10056,
#   10076,
#   10154,
#   10717,
#   10750,
#   11088,
#   11270,
#   11560,
#   11570,
#   11623,
#   12474,
#   12576,
#   12626,
#   12660,
#   12784,
#   12933,
#   12990,
#   6829,
#   6844,
#   6845,
#   6893,
#   6896,
#   6897,
#   12605,
#   11874,
#   1000358,
#   1000360,
#   1000361,
#   1000537,
#   13054,
#   13055,
#   13084,
#   15252,
#   16209,
#   16226,
#   16377,
#   16565,
#   16931,
#   16970,
#   17350,
#   13590,
#   13610,
#   1000559,
#   1000737,
#   18422,
#   51013,
#   1000932,
#   50537,
#   50630,
#   50740,
#   50929,
#   50348,
#   1002486,
#   1002487,
#   1002930,
#   18822,
#   19798,
#   52019,
#   52132,
#   18965,
#   52301,
#   52720,
#   20338,
#   53723,
#   1004014,
#   52782,
#   53569,
#   21750,
#   22101,
#   54989,
#   55074,
#   22364,
#   53857,
#   54437,
#   55061,
#   22642,
#   23488,
#   28797,
#   29068,
#   29455,
#   29662,
#   32111,
#   32175,
#   32271,
#   29341,
#   29596,
#   30605,
#   31061,
#   1003493,
#   1324,
#   1493,
#   2758,
#   33746,
#   33773,
#   35316,
#   1004016,
#   4242,
#   4539,
#   6741,
#   4393,
#   6510,
#   11081,
#   1000127,
#   14608,
#   15535,
#   16288,
#   50243,
#   1000970,
#   18085,
#   50279,
#   1002810,
#   19423,
#   19664,
#   19667,
#   20709,
#   53293,
#   1003956,
#   20985,
#   53074,
#   53162,
#   53444,
#   20716,
#   54371,
#   54645,
#   24501,
#   27936,
#   25484,
#   55378,
#   27804,
#   28543,
#   31468,
#   1205,
#   6438,
#   50354,
#   18817,
#   18859,
#   52040,
#   1003553,
#   20073,
#   22467,
#   2764,
#   6276,
#   10113,
#   13775,
#   22450,
#   30948,
#   1251,
#   1002662,
#   23434,
#   33106,
#   33735,
#   34097,
#   12792,
#   12980,
#   1000082,
#   16639,
#   1000797,
#   17893,
#   50504,
#   1001487,
#   17856,
#   17879,
#   54804,
#   21554,
#   23308,
#   55704,
#   25718,
#   60065,
#   23450,
#   1002834,
#   28055,
#   29977,
#   31346,
#   32669,
#   2816,
#   3963,
#   6402,
#   10100,
#   16212,
#   1000969,
#   18948,
#   18984,
#   19384,
#   51934,
#   53167,
#   1003672,
#   27932,
#   33020,
#   4216,
#   4485,
#   4528,
#   4726,
#   4809,
#   4848,
#   6619,
#   6747,
#   6754,
#   6746,
#   11116,
#   11518,
#   6933,
#   12179,
#   1000903,
#   51299,
#   1001575,
#   1001742,
#   18554,
#   19858,
#   52577,
#   1001967,
#   20160,
#   20321,
#   20919,
#   1003177,
#   22038,
#   22106,
#   24244,
#   25771,
#   23194,
#   24361,
#   55774,
#   25003,
#   25462,
#   1367,
#   34817,
#   2942,
#   4956,
#   6417,
#   6505,
#   11219,
#   13291,
#   50341,
#   21679,
#   21783,
#   60089,
#   2309,
#   33630,
#   33737,
#   33742,
#   33748,
#   34168,
#   1004058,
#   10176,
#   11256,
#   13315,
#   1000630,
#   1002236,
#   1003951,
#   1003955,
#   21795,
#   24472,
#   27587,
#   25501,
#   27584,
#   35016,
#   1002176,
#   54383,
#   55607,
#   6232,
#   1000758,
#   53665,
#   60075,
#   34247,
#   34338,
#   35722,
#   4012,
#   4049,
#   4502,
#   11060,
#   11441,
#   12701,
#   6930,
#   1000413,
#   13376,
#   13410,
#   17286,
#   51266,
#   1001139,
#   52776,
#   53175,
#   53197,
#   21724,
#   55034,
#   25464,
#   27197,
#   24811,
#   682,
#   10159,
#   11629,
#   1001966,
#   1002679,
#   53190,
#   34265,
#   34708,
#   6591,
#   6662,
#   6776,
#   7027,
#   1000185,
#   1000254,
#   1000318,
#   13312,
#   50228,
#   16605,
#   1000441,
#   1001144,
#   1001146,
#   1001145,
#   1001865,
#   1002713,
#   1002714,
#   52179,
#   19767,
#   51928,
#   20296,
#   20297,
#   20305,
#   22125,
#   25532,
#   25265,
#   55634,
#   32327,
#   32739,
#   1002712,
#   29874,
#   32336,
#   1002715,
#   33849,
#   3625,
#   6664,
#   19071,
#   52266,
#   1004045,
#   53304,
#   24637,
#   25346,
#   26806,
#   27091,
#   55452,
#   33884,
#   11371,
#   15646,
#   1002508,
#   51488,
#   3028,
#   4893,
#   6997,
#   16051,
#   16235,
#   1002718,
#   51718,
#   52791,
#   53055,
#   25654,
#   25741,
#   6344,
#   7029,
#   50199,
#   18119,
#   50274,
#   1002732,
#   51637,
#   31457,
#   6431,
#   1003309,
#   6852,
#   1000023,
#   50282,
#   1002831,
#   52825,
#   50764,
#   1003334,
#   21821,
#   27119,
#   25838,
#   55696],
#  '217.169.1.17': [50608,
#   1,
#   1003292,
#   818,
#   102,
#   1003747,
#   3102,
#   3274,
#   4501,
#   4604,
#   4982,
#   6405,
#   6695,
#   6400,
#   6499,
#   10001,
#   10015,
#   10501,
#   10735,
#   10860,
#   11525,
#   11587,
#   11702,
#   11713,
#   11802,
#   11835,
#   12076,
#   12796,
#   10102,
#   10806,
#   11499,
#   6892,
#   7101,
#   11576,
#   12356,
#   1000457,
#   13358,
#   13476,
#   13649,
#   13665,
#   13745,
#   14577,
#   15324,
#   15838,
#   14647,
#   15793,
#   16130,
#   14934,
#   1000944,
#   1001789,
#   18418,
#   18655,
#   1002111,
#   1002115,
#   1002146,
#   1002147,
#   1002183,
#   1002193,
#   1002576,
#   1002787,
#   1002814,
#   51755,
#   52675,
#   53031,
#   1003158,
#   20189,
#   52778,
#   53496,
#   53525,
#   53749,
#   22344,
#   54438,
#   54959,
#   21508,
#   22890,
#   22959,
#   24550,
#   55550,
#   55735,
#   28498,
#   31275,
#   32430,
#   1002114,
#   28651,
#   1002113,
#   28740,
#   1002994,
#   1002995,
#   1003021,
#   1003026,
#   1003037,
#   2234,
#   3178,
#   6648,
#   7051,
#   1000422,
#   1000430,
#   1000431,
#   1000438,
#   1000998,
#   1001043,
#   1001066,
#   1001264,
#   1001369,
#   1001668,
#   1001669,
#   1001675,
#   1001708,
#   1001720,
#   1001727,
#   1001728,
#   18113,
#   50631,
#   1001012,
#   1001047,
#   1001072,
#   1001333,
#   1001683,
#   1001696,
#   1001705,
#   1001722,
#   1001763,
#   1002992,
#   1000434,
#   1001828,
#   1001841,
#   1001847,
#   1001849,
#   1001852,
#   1001919,
#   1001920,
#   1001922,
#   1001927,
#   1001928,
#   1001934,
#   1001976,
#   1001981,
#   1002052,
#   1002054,
#   1002233,
#   1002401,
#   1002403,
#   1002991,
#   52516,
#   1003019,
#   53434,
#   1002997,
#   1003004,
#   1003008,
#   1003020,
#   1003028,
#   1003030,
#   1003031,
#   1003032,
#   1004043,
#   24774,
#   25438,
#   32589,
#   1447,
#   167,
#   2047,
#   2374,
#   34857,
#   35027,
#   667,
#   2463,
#   3264,
#   3555,
#   35644,
#   3967,
#   4367,
#   4823,
#   4877,
#   3081,
#   10615,
#   10782,
#   11035,
#   11540,
#   12282,
#   11251,
#   11740,
#   12341,
#   13432,
#   13538,
#   14256,
#   15698,
#   16984,
#   50001,
#   50144,
#   17297,
#   1001115,
#   17948,
#   17984,
#   17950,
#   1002469,
#   1002674,
#   19119,
#   19700,
#   19723,
#   19855,
#   51562,
#   52429,
#   52519,
#   52722,
#   52851,
#   52991,
#   53517,
#   53535,
#   1003708,
#   1003762,
#   1003880,
#   20174,
#   53742,
#   53018,
#   1004164,
#   21690,
#   54122,
#   54234,
#   55032,
#   21824,
#   54510,
#   54891,
#   55084,
#   23360,
#   24276,
#   26023,
#   26077,
#   26156,
#   26232,
#   55354,
#   55404,
#   22583,
#   23813,
#   24069,
#   25915,
#   26489,
#   26587,
#   26996,
#   55276,
#   60057,
#   60092,
#   28587,
#   30572,
#   31235,
#   31349,
#   32399,
#   28447,
#   28512,
#   28594,
#   28631,
#   28860,
#   30220,
#   32561,
#   1003045,
#   1003525,
#   2440,
#   2554,
#   33866,
#   453,
#   898,
#   2566,
#   54762,
#   54764,
#   4041,
#   13503,
#   16498,
#   50138,
#   54246,
#   6777,
#   6779,
#   1002844,
#   12207,
#   50085,
#   19414,
#   19496,
#   53411,
#   54668,
#   55412],
#  '63.218.229.170': [1003162,
#   1033,
#   35517,
#   1004065,
#   1004066,
#   1004140,
#   4800,
#   6594,
#   6676,
#   6718,
#   6726,
#   1004505,
#   6970,
#   7091,
#   7092,
#   6917,
#   6918,
#   1000379,
#   13536,
#   13807,
#   14075,
#   14076,
#   14672,
#   14772,
#   50165,
#   14623,
#   15984,
#   1001461,
#   1001407,
#   18369,
#   1002026,
#   19704,
#   1003371,
#   1004002,
#   19970,
#   1004501,
#   54623,
#   25086,
#   28837,
#   30683,
#   1004020,
#   1004064,
#   6887,
#   16968,
#   19092,
#   19160,
#   1003499,
#   1004264,
#   1004316,
#   1004373,
#   52350,
#   54271,
#   1001463,
#   1004317,
#   20896,
#   1004290,
#   4430,
#   14042,
#   52918,
#   1002126,
#   1002161,
#   1002171,
#   6477,
#   50327,
#   33257,
#   1004314,
#   6568,
#   12967,
#   13022,
#   13015,
#   53307,
#   1003862,
#   1004263,
#   1004313,
#   1004315,
#   55215,
#   33413,
#   33512,
#   1004304,
#   1002159,
#   52594,
#   1002726,
#   21101,
#   54220,
#   23473,
#   24204,
#   24265,
#   6345,
#   6586,
#   1001791,
#   1001785,
#   1002125,
#   20151,
#   1002841,
#   7102,
#   1002163,
#   6681,
#   1002497,
#   21048,
#   1000599,
#   54395,
#   7007,
#   23415,
#   7016,
#   50524,
#   1002166,
#   1002168,
#   54818,
#   22938,
#   22938,
#   22938,
#   22938,
#   22938,
#   22938,
#   22938,
#   22938],
#  '107.154.13.242': [6836,
#   19082,
#   1003459,
#   1145,
#   33759,
#   1003702,
#   3588,
#   4307,
#   6274,
#   6775,
#   6264,
#   6434,
#   6794,
#   12652,
#   6898,
#   7011,
#   7121,
#   7043,
#   1000260,
#   13857,
#   14300,
#   18599,
#   1001041,
#   1001507,
#   1001820,
#   1002242,
#   1002294,
#   19131,
#   51754,
#   52344,
#   52574,
#   52883,
#   52886,
#   1003891,
#   55147,
#   23127,
#   26056,
#   28600,
#   1000109,
#   1003524,
#   1003528,
#   1003530,
#   1003533,
#   125,
#   2111,
#   34234,
#   34770,
#   1003536,
#   6101,
#   10185,
#   10394,
#   10456,
#   10905,
#   12100,
#   12116,
#   12154,
#   6811,
#   15749,
#   15958,
#   16058,
#   16949,
#   1000785,
#   1001550,
#   50338,
#   50379,
#   50620,
#   50787,
#   51053,
#   51350,
#   1001552,
#   1001816,
#   1002766,
#   1002785,
#   1002799,
#   19053,
#   19270,
#   51636,
#   51807,
#   52326,
#   52419,
#   52607,
#   1000296,
#   53279,
#   53798,
#   1003495,
#   1003526,
#   1003527,
#   1003529,
#   1003531,
#   1003532,
#   1003538,
#   1003541,
#   22447,
#   53929,
#   54129,
#   55242,
#   21806,
#   53965,
#   55050,
#   26250,
#   26449,
#   23000,
#   55330,
#   30874,
#   31116,
#   31313,
#   32083,
#   32567,
#   60957,
#   1058,
#   2592,
#   34732,
#   1001467,
#   19148,
#   19946,
#   52417,
#   52916,
#   53110,
#   53542,
#   53794,
#   25156,
#   55389,
#   31169,
#   3971,
#   6774,
#   6890,
#   14779,
#   15072,
#   50094,
#   50244,
#   17830,
#   17908,
#   50514,
#   51955,
#   52208,
#   52964,
#   21001,
#   4981,
#   1000004,
#   1000006,
#   1002220,
#   20756,
#   7052,
#   54121,
#   1002532,
#   52423,
#   54294]}

# %%
import os
import time
from IPy import IP

# %%
from ripe.atlas.cousteau import (
  Ping,
  Traceroute,
  AtlasSource,
  AtlasCreateRequest
)

# %%
class Measurement:
    def __init__(self, target=[], prb_lst=[], key_lst=[]):
        self.key_lst = key_lst
        self.target = target
        self.prb_lst = prb_lst
        self.mtr_mid = []

    def ping(self,ip,pre_list,api_key):

        ping = Ping(
            af = 4,
            target=ip,
            description=f"ping to {ip}",
            protocol="ICMP", 
            resolve_on_probe=True
        )
        
        source3 = AtlasSource(
            type="probes",
            value=pre_list,
            requested=len(pre_list)
        )

        atlas_request = AtlasCreateRequest(
            key=api_key,
            measurements=[ping],
            sources=[source3],
            is_oneoff=True
        )
        (is_success,response) = atlas_request.create()
        if is_success:
            return response['measurements'][0]        #return msm
        else:
            print(response)
            return 'fail'
    
    def getmtrid(self, mtr_lst=[]):        #assign the measurement_id instead of running a new round measurement
        #self.get_probe()
        self.mtr_mid = mtr_lst 
    
    def measurement(self,fn):
        if len(self.prb_lst) != 0:
            num = len(self.prb_lst) / 1000
            probe_lst = np.array_split(self.prb_lst, num + 1)
            files = os.listdir("../dataset/srprobe_lst/")
            filename = sorted(files,reverse=True)[0]                      # get the latest rsprobe_lst, get valid_probe_pd
            self.valid_probe_pd = pd.read_csv(f"../dataset/srprobe_lst/{filename}", index_col=0)
        else:
            self.get_probe()
            print("get probes done, running measurement")
            srprobe_lst = self.valid_probe_pd[self.valid_probe_pd['stable']==True]['id'].to_list()
            num = len(srprobe_lst) / 1000
            probe_lst = np.array_split(srprobe_lst, num+1)   #make sure number of probes of each splited list is less than 1000
        self.mtr_mid = []
        i = 0
        for ip in self.target:
            for split_probe in probe_lst:
                mid = "fail"
                while mid == "fail" and i < len(self.key_lst):
                    mid = fn(ip, ",".join([str(x) for x in split_probe]), self.key_lst[i])
                    i = i + 1
                if mid != "fail":
                    self.mtr_mid.append(mid)
                else:
                    print(f"measurement fail, your finished measurement id is {self.mtr_mid}")
        print("measurement done!")
    def ping_result(self):
        measure_pd_lst = []
        for i in range(len(self.mtr_mid)):
            measure_pd_lst.append(pd.read_json("https://atlas.ripe.net/api/v2/measurements/%s/results/?format=json&filename=RIPE-Atlas-measurement-%s.json" % (self.mtr_mid[i], self.mtr_mid[i])))
        self.measure_pd = pd.concat(measure_pd_lst).reset_index()

# %%
measure_ins_lst = []
measure_pd_lst = []
for target, prb_lst in measure_dict_x.items():
    a = Measurement(target=[target], key_lst=["42e0ca73-7081-4f54-a7f8-dbb55321afe6","f0101915-0ccb-45ad-ac67-ae0c8057f206","a39c32a0-3938-407e-88c1-94a9ad077234","93f4a793-78ae-48ac-8440-1c7ce633a589","5f43bd6d-51b6-474a-843e-77399185837d","d58aa165-c6b1-466d-8a53-adf07e883d8f"], prb_lst=prb_lst)
    measure_ins_lst.append(a)
    a.measurement(a.ping)
    print(a.mtr_mid)
    time.sleep(10)
    a.ping_result()
    a.measure_pd.rename(columns={"avg":target}, inplace=True)
    if "prb_id" in a.measure_pd.columns:
        a.measure_pd.set_index("prb_id")
        measure_pd_lst.append(a.measure_pd[[target]])
# Out:
# measurement done!
# [56409286]
# measurement done!
# [56409294]
# measurement done!
# [56409302]
# measurement done!
# [56409309]
# measurement done!
# [56409317]
# measurement done!
# [56409326]
# measurement done!
# [56409333]
# measurement done!
# [56409341]
# measurement done!
# [56409348]
# measurement done!
# [56409361]

# %%
def dict_slice(adict, start, end):
    keys = adict.keys()
    dict_slice = {}
    for k in list(keys)[start:end]:
        dict_slice[k] = adict[k]
    return dict_slice

# %%
measure_dict_x = dict_slice(measure_dict, 23, -1)

# %%
for target, prb_lst in measure_dict.items():
    print(target)
# Out:
# 212.25.27.124 22 -1
# 128.241.13.250 22 -1
# 5.10.135.250 22 -1
# 87.186.181.234 22 -1
# 185.23.196.245 22 -1
# 84.110.104.138 22 -1
# 46.40.68.1 22 -1
# 217.169.1.17 22 -1
# 128.241.13.242 22 -1
# 193.149.1.87 22 -1
# 46.59.112.142 22 -1
# 121.78.89.186 22 -1
# 182.79.186.74 22 -1
# 62.115.187.154 22 -1
# 182.79.186.90 22 -1
# 185.6.36.156 22 -1
# 8.243.136.186 22 -1
# 107.154.222.242 22 -1
# 63.216.242.138 22 -1
# 180.235.105.165 22 -1
# 210.10.203.2 22 -1
# 58.163.93.118 22 -1
# 192.168.100.1 22 -1
# 128.241.13.106 22 -1
# 123.255.90.82 22 -1
# 63.218.247.18 22 -1
# 75.149.230.98 22 -1
# 107.154.15.242 22 -1
# 107.154.8.242 22 -1
# 41.60.135.61 22 -1
# 196.250.236.139 22 -1
# 63.218.229.170 22 -1
# 107.154.13.242 22 -1
# 107.154.14.242 22 -1

# %%
a.measure_pd.rename(columns={"avg":'212.25.27.124'}, inplace=True)

# %%
a.measure_pd['212.25.27.124']
# Out:
# 0     7.913468
# 1    21.076878
# 2    34.137282
# 3     7.913468
# 4    21.076878
# 5    34.137282
# Name: 212.25.27.124, dtype: float64

# %%
len(measure_dict["212.25.27.124"])
# Out:
# 1594

# %%
b = Measurement(key_lst=["42e0ca73-7081-4f54-a7f8-dbb55321afe6","f0101915-0ccb-45ad-ac67-ae0c8057f206","a39c32a0-3938-407e-88c1-94a9ad077234","93f4a793-78ae-48ac-8440-1c7ce633a589","5f43bd6d-51b6-474a-843e-77399185837d","d58aa165-c6b1-466d-8a53-adf07e883d8f"])
b.getmtrid([56404902, 56404902])
b.ping_result()
b.measure_pd
# Out:
# [56404902, 56404902]
#    index    fw   mver  lts       dst_name  af       dst_addr         src_addr  \
# 0      0  5040  2.4.1   49  212.25.27.124   4  212.25.27.124       172.17.0.2
# 1      1  5080  2.6.2   13  212.25.27.124   4  212.25.27.124    192.168.178.2
# 2      2  5080  2.6.2   34  212.25.27.124   4  212.25.27.124  192.168.178.235
# 3      3  5080  2.6.2   21  212.25.27.124   4  212.25.27.124      188.74.47.6
# 4      0  5040  2.4.1   49  212.25.27.124   4  212.25.27.124       172.17.0.2
# 5      1  5080  2.6.2   13  212.25.27.124   4  212.25.27.124    192.168.178.2
# 6      2  5080  2.6.2   34  212.25.27.124   4  212.25.27.124  192.168.178.235
# 7      3  5080  2.6.2   21  212.25.27.124   4  212.25.27.124      188.74.47.6
#
#   proto  ttl  ...        avg    msm_id   prb_id           timestamp  msm_name  \
# 0  ICMP   60  ...   7.913468  56404902  1003842 2023-06-29 09:38:36      Ping
# 1  ICMP   54  ...  21.076878  56404902    21472 2023-06-29 09:38:34      Ping
# 2  ICMP   59  ...  34.137282  56404902    35681 2023-06-29 09:38:35      Ping
# 3  ICMP   60  ...  12.076778  56404902    51072 2023-06-29 09:38:38      Ping
# 4  ICMP   60  ...   7.913468  56404902  1003842 2023-06-29 09:38:36      Ping
# 5  ICMP   54  ...  21.076878  56404902    21472 2023-06-29 09:38:34      Ping
# 6  ICMP   59  ...  34.137282  56404902    35681 2023-06-29 09:38:35      Ping
# 7  ICMP   60  ...  12.076778  56404902    51072 2023-06-29 09:38:38      Ping
#
#              from  type  group_id  step  stored_timestamp
# 0  95.174.224.137  ping  56404902   NaN        1688031517
# 1     87.2.82.228  ping  56404902   NaN        1688031515
# 2  145.224.98.201  ping  56404902   NaN        1688031515
# 3     188.74.47.6  ping  56404902   NaN        1688031521
# 4  95.174.224.137  ping  56404902   NaN        1688031517
# 5     87.2.82.228  ping  56404902   NaN        1688031515
# 6  145.224.98.201  ping  56404902   NaN        1688031515
# 7     188.74.47.6  ping  56404902   NaN        1688031521
#
# [8 rows x 27 columns]

# %%
measure_dict.keys()
# Out:
# dict_keys(['217.29.66.201', '91.206.52.242', '128.241.13.250', '213.242.111.235', '87.186.181.234', '185.1.8.39', '84.110.104.138', '185.74.20.238', '213.46.182.188', '80.249.208.124', '185.1.192.144', '213.242.110.162', '195.182.219.89', '121.78.89.186', '182.79.186.74', '128.241.15.26', '62.115.187.154', '182.79.186.90', '185.6.36.156', '8.243.136.186', '187.16.220.160', '186.10.50.42', '128.241.15.18', '43.243.21.97', '210.10.203.2', '58.163.93.118', '192.168.20.1', '206.126.237.203', '198.32.181.61', '123.255.90.82', '192.72.108.166', '116.206.112.49', '208.115.136.143', '4.14.254.114', '198.32.243.117', '206.223.118.231', '196.60.9.87', '196.250.236.139', '206.51.46.26', '63.218.229.170', '218.100.44.33', '103.28.75.134', '206.223.116.210', '4.7.26.34', '206.81.81.178', '23.251.105.26', '67.69.211.102'])

# %%
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
test_analysis.phop_pd[~pd.isna(test_analysis.phop_pd['rdns-geo'])]

# %%
import socket

# %%
socket.gethostbyaddr("10.200.255.16")[0]
