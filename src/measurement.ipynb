# %%
import requests
import pandas as pd

# %%
valid_probes = []
current_page = "https://atlas.ripe.net:443/api/v2/probes/?status=1"

while True:
    page = requests.get(current_page)
    if page.json()['next'] != None:
        current_page = page.json()['next']
    else:
        break
    valid_probes += page.json()['results']

valid_probe_pd = pd.DataFrame(valid_probes)

# %%
valid_probe_pd
# Out:
#            address_v4                           address_v6   asn_v4    asn_v6  \
# 0                None   2a10:3781:e22:1:220:4aff:fec8:23d7      NaN  206238.0
# 1        77.174.76.85  2a02:a467:f500:1:220:4aff:fec8:2532   1136.0    1136.0
# 2                None                                 None  50266.0       NaN
# 3      82.217.219.124                                 None  33915.0       NaN
# 4         83.81.82.33                                 None  33915.0       NaN
# ...               ...                                  ...      ...       ...
# 12895  185.18.148.227                   2a04:b80:1:18::227  42160.0   42160.0
# 12896   85.115.26.149    2a02:788:14:1:d41f:6fff:fe0a:6d52  12843.0   12843.0
# 12897            None                                 None    577.0       NaN
# 12898  193.200.27.186                                 None  49289.0       NaN
# 12899            None  2a10:200:1:2000:fcc4:e6ff:feda:50c9      NaN  208059.0
#
#       country_code                      description  first_connected  \
# 0               NL          Robert #1 100/10 XS4All       1288367583
# 1               NL               Ανδρέας@Άμστερνταμ       1288372715
# 2               NL                              UPC       1288619463
# 3               NL       @milan ZIGGO 200/20 Mbit/s       1288686777
# 4               NL  @dfk ZIGGO 1000/75 Mbit/s Cable       1288619044
# ...            ...                              ...              ...
# 12895           BE                           Lorlea       1684826475
# 12896           DE                                        1684836250
# 12897           CA                                        1684867993
# 12898           IT         Mediaveneto FWA 50/50 Mb       1684874463
# 12899           DE                  GRMML-Probe-003       1684932640
#
#                                                 geometry       id  is_anchor  \
# 0      {'type': 'Point', 'coordinates': [4.9275, 52.3...        1      False
# 1      {'type': 'Point', 'coordinates': [4.9375, 52.3...        3      False
# 2      {'type': 'Point', 'coordinates': [4.9175, 52.3...        6      False
# 3      {'type': 'Point', 'coordinates': [6.0075, 51.2...        7      False
# 4      {'type': 'Point', 'coordinates': [6.0375, 51.2...        8      False
# ...                                                  ...      ...        ...
# 12895  {'type': 'Point', 'coordinates': [3.2405, 51.1...  1005876      False
# 12896  {'type': 'Point', 'coordinates': [8.4105, 49.0...  1005878      False
# 12897  {'type': 'Point', 'coordinates': [-79.3085, 43...  1005880      False
# 12898  {'type': 'Point', 'coordinates': [11.4115, 45....  1005881      False
# 12899  {'type': 'Point', 'coordinates': [9.4915, 51.2...  1005882      False
#
#        is_public  last_connected        prefix_v4        prefix_v6  \
# 0           True      1686547810             None   2a10:3780::/29
# 1           True      1686547810    77.174.0.0/16   2a02:a400::/25
# 2          False      1686547810    82.174.0.0/16             None
# 3           True      1686547810  82.217.128.0/17             None
# 4           True      1686547810     83.80.0.0/14             None
# ...          ...             ...              ...              ...
# 12895       True      1686548069  185.18.148.0/23  2a04:b80:1::/48
# 12896       True      1686548069    85.115.0.0/19    2a02:788::/29
# 12897      False      1686548069     74.14.0.0/16             None
# 12898       True      1686548069  193.200.27.0/24             None
# 12899       True      1686548069             None  2a10:200:1::/48
#
#                                                   status  status_since  \
# 0      {'id': 1, 'name': 'Connected', 'since': '2023-...    1685124966
# 1      {'id': 1, 'name': 'Connected', 'since': '2023-...    1685440128
# 2      {'id': 1, 'name': 'Connected', 'since': '2023-...    1685386046
# 3      {'id': 1, 'name': 'Connected', 'since': '2023-...    1680813859
# 4      {'id': 1, 'name': 'Connected', 'since': '2023-...    1686154804
# ...                                                  ...           ...
# 12895  {'id': 1, 'name': 'Connected', 'since': '2023-...    1684827539
# 12896  {'id': 1, 'name': 'Connected', 'since': '2023-...    1684836250
# 12897  {'id': 1, 'name': 'Connected', 'since': '2023-...    1685562395
# 12898  {'id': 1, 'name': 'Connected', 'since': '2023-...    1685807871
# 12899  {'id': 1, 'name': 'Connected', 'since': '2023-...    1686164525
#
#                                                     tags  total_uptime   type  \
# 0      [{'name': 'DSL', 'slug': 'dsl'}, {'name': 'Hom...     386333790  Probe
# 1      [{'name': 'Home', 'slug': 'home'}, {'name': 'N...     386645633  Probe
# 2      [{'name': 'Home', 'slug': 'home'}, {'name': 'N...     345046051  Probe
# 3      [{'name': 'Cable', 'slug': 'cable'}, {'name': ...     388053910  Probe
# 4      [{'name': 'Cable', 'slug': 'cable'}, {'name': ...     384548165  Probe
# ...                                                  ...           ...    ...
# 12895  [{'name': 'Datacentre', 'slug': 'datacentre'},...       1721586  Probe
# 12896  [{'name': 'system: Resolves A Correctly', 'slu...       1711819  Probe
# 12897  [{'name': 'Fibre', 'slug': 'fibre'}, {'name': ...       1669781  Probe
# 12898  [{'name': 'Home', 'slug': 'home'}, {'name': 'w...       1673089  Probe
# 12899  [{'name': 'Native IPv6', 'slug': 'native-ipv6'...       1613759  Probe
#
#        stable
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 12895   False
# 12896   False
# 12897   False
# 12898   False
# 12899   False
#
# [12900 rows x 20 columns]

# %%
def findStableTag(x):
    for tag in x:
        for index, item in tag.items():
            if item == "system-ipv4-stable-1d":
                return True
    return False

# %%
valid_probe_pd["stable"] = valid_probe_pd['tags'].apply(lambda x: findStableTag(x))

# %%
valid_probe_pd["stable"].value_counts()
# Out:
# True     10919
# False     1981
# Name: stable, dtype: int64

# %%
valid_probe_pd["tags"].loc[1]
# Out:
# [{'name': 'Home', 'slug': 'home'},
#  {'name': 'NAT', 'slug': 'nat'},
#  {'name': 'system: V1', 'slug': 'system-v1'},
#  {'name': 'system: Resolves A Correctly',
#   'slug': 'system-resolves-a-correctly'},
#  {'name': 'system: Resolves AAAA Correctly',
#   'slug': 'system-resolves-aaaa-correctly'},
#  {'name': 'system: IPv4 Works', 'slug': 'system-ipv4-works'},
#  {'name': 'system: IPv6 Works', 'slug': 'system-ipv6-works'},
#  {'name': 'system: IPv4 Capable', 'slug': 'system-ipv4-capable'},
#  {'name': 'system: IPv6 Capable', 'slug': 'system-ipv6-capable'},
#  {'name': 'system: IPv4 RFC1918', 'slug': 'system-ipv4-rfc1918'},
#  {'name': 'system: IPv4 Stable 30d', 'slug': 'system-ipv4-stable-30d'},
#  {'name': 'system: IPv4 Stable 90d', 'slug': 'system-ipv4-stable-90d'},
#  {'name': 'system: IPv4 Stable 1d', 'slug': 'system-ipv4-stable-1d'},
#  {'name': 'system: Firewall problem suspected',
#   'slug': 'system-firewall-problem-suspected'}]

# %%
import datetime

# %%
sprobe_lst = valid_probe_pd[valid_probe_pd['stable']==True]['id'].to_list()

# %%
filename = datetime.date.today().strftime("%Y-%m-%d")
with open(f"../dataset/srprobe_lst/{filename}", "w+") as f:
    f.write(" ".join(map(str,sprobe_lst)))

# %% [markdown]
# # measurement

# %%
ATLAS_API_KEY = ["42e0ca73-7081-4f54-a7f8-dbb55321afe6","f0101915-0ccb-45ad-ac67-ae0c8057f206","a39c32a0-3938-407e-88c1-94a9ad077234","93f4a793-78ae-48ac-8440-1c7ce633a589","5f43bd6d-51b6-474a-843e-77399185837d","d58aa165-c6b1-466d-8a53-adf07e883d8f"]

# %%
import requests

# %%
result = requests.get(f"https://api.hoiho.caida.org/lookups/ae3-4.RT.IRX.FKT.DE.retn.net")

# %%
eval(result.content)
# Out:
# {'summary': {'ruleset_date': '2023-03',
#   'hostnames_requested': 1,
#   'hostnames_matched': 1},
#  'matches': [{'hostname': 'ae3-4.rt.irx.fkt.de.retn.net',
#    'match_strs': ['fkt', 'de'],
#    'match_meanings': ['iata', 'cc'],
#    'iata': 'fkt',
#    'place': 'Frankfurt am Main',
#    'st': 'HE',
#    'cc': 'DE',
#    'lat': '50.115520',
#    'lng': '8.684170'}]}

# %%
if "matches" in eval(result.content).keys():
    print(eval(result.content)['matches'])
    loc = f""
# Out:
# [{'hostname': 'ae3-4.rt.irx.fkt.de.retn.net', 'match_strs': ['fkt', 'de'], 'match_meanings': ['iata', 'cc'], 'iata': 'fkt', 'place': 'Frankfurt am Main', 'st': 'HE', 'cc': 'DE', 'lat': '50.115520', 'lng': '8.684170'}]
